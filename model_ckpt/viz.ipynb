# %%
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
from tqdm import tqdm
import heapq
import numpy as np

with open('./full_graph_split1_eval.pkl', 'rb') as f:
    res = pickle.load(f)
result = pd.DataFrame(res['result'])

with open('./graphmask_output_indication.pkl', 'rb') as f:
    d_gm = pickle.load(f)
    
with open('./attention_output_indication.pkl', 'rb') as f:
    d_att = pickle.load(f)
    
with open('./gnnexplainer_output_indication.pkl', 'rb') as f:
    d_ge = pickle.load(f)

# %%
def preprocess(d):
    d = d[~d.y_name.str.contains('CYP')]
    d = d[~d.x_name.str.contains('CYP')]
    d = d.rename(columns = {'indication_layer1_att': 'layer1_att', 'indication_layer2_att': 'layer2_att'})
    return d

# %%
d_gm = preprocess(d_gm)
d_ge = preprocess(d_ge)
d_att = preprocess(d_att)

# %%
def build_graph(df):
    G = nx.MultiDiGraph()
    for _, row in tqdm(df.iterrows()):
        # Add nodes with their types
        G.add_node(row['x_name'], node_type=row['x_type'])
        G.add_node(row['y_name'], node_type=row['y_type'])

        # Add edges with relation type and weights
        G.add_edge(row['x_name'], row['y_name'], relation=row['relation'],
                   layer1_att=row['layer1_att'], layer2_att=row['layer2_att'])
    return G

def get_two_hop_neighborhood(G, node_id):
    # Get neighbors within two hops
    neighbors_one_hop = set(nx.all_neighbors(G, node_id))
    neighbors_two_hop = set()
    for n in neighbors_one_hop:
        neighbors_two_hop.update(nx.all_neighbors(G, n))
    return neighbors_one_hop.union(neighbors_two_hop)

def find_relation_specific_paths(G, start_id, end_id, max_depth=4):
    paths = []
    for path in nx.all_simple_paths(G, source=start_id, target=end_id, cutoff=max_depth):
        # Construct relation-specific path
        relation_path = [start_id]
        for i in range(len(path) - 1):
            relation = G[path[i]][path[i + 1]][0]['relation']  # Assuming one relation per edge for simplicity
            relation_path.extend([relation, path[i + 1]])
        paths.append(relation_path)
    return paths

def get_two_hop_neighborhood_enrichment_per_relation(G, node_id, K, K2, relation_averages, enrichment = True):
    
    # First hop: Get the top K neighbors for each relation type
    neighbors_by_relation = {}
    for neighbor in G[node_id]:
        for edge_key in G[node_id][neighbor]:
            edge_data = G[node_id][neighbor][edge_key]
            relation = edge_data['relation']
            weight = edge_data['layer1_att'] + edge_data['layer2_att']
            if enrichment:
                avg_weight = relation_averages[relation]
                relative_increase = ((weight - avg_weight) / avg_weight) * 100
            else:
                relative_increase = weight
            if relation not in neighbors_by_relation:
                neighbors_by_relation[relation] = []
            heapq.heappush(neighbors_by_relation[relation], (-relative_increase, neighbor))

    # Select the top K neighbors for each relation type
    first_hop_neighbors = set()
    for relation, neighbors in neighbors_by_relation.items():
        top_neighbors = [neighbor for _, neighbor in heapq.nlargest(K, neighbors)]
        first_hop_neighbors.update(top_neighbors)

    # Second hop: Repeat the process for each neighbor in first_hop_neighbors
    second_hop_neighbors = set()
    for first_hop_neighbor in first_hop_neighbors:
        neighbors_by_relation = {}
        for neighbor in G[first_hop_neighbor]:
            for edge_key in G[first_hop_neighbor][neighbor]:
                edge_data = G[first_hop_neighbor][neighbor][edge_key]
                relation = edge_data['relation']
                weight = edge_data['layer1_att'] + edge_data['layer2_att']
                
                if enrichment:
                    avg_weight = relation_averages[relation]
                    relative_increase = ((weight - avg_weight) / avg_weight) * 100
                else:
                    relative_increase = weight

                if relation not in neighbors_by_relation:
                    neighbors_by_relation[relation] = []
                heapq.heappush(neighbors_by_relation[relation], (-relative_increase, neighbor))

        for relation, neighbors in neighbors_by_relation.items():
            top_neighbors = [neighbor for _, neighbor in heapq.nlargest(K, neighbors)]
            second_hop_neighbors.update(top_neighbors)

    return first_hop_neighbors.union(second_hop_neighbors)

def score_path_enrichment(G, path, relation_averages, enrichment = True):
    score = 0
    path_length = len(path) // 2  # Number of edges in the path

    for i in range(0, path_length * 2, 2):
        node1 = path[i]
        relation = path[i + 1]
        node2 = path[i + 2]

        if (node1, node2) in G.edges():
            for edge_key in G[node1][node2]:
                edge_data = G[node1][node2][edge_key]
                if edge_data['relation'] == relation:
                    weight = edge_data['layer1_att'] + edge_data['layer2_att']
                    if enrichment:
                        avg_weight = relation_averages[relation]
                        # Calculate percentage relative increase
                        relative_increase = ((weight - avg_weight) / avg_weight) * 100
                    else:
                        relative_increase = weight
                    score += relative_increase

    score /= path_length

    return score

def print_beautiful_path(path):
    path = [i if 'rev' not in i else i[4:] for i in path]
    return ' -> '.join(path)

def print_beautiful_paths(paths):
    return [print_beautiful_path(i) for i in paths]

def group_paths_by_meta_paths_with_node_types(paths, G):
    meta_paths_dict = {}

    for path in paths:
        # Extract the meta path with node types and relation types
        meta_path = []
        for i in range(len(path)):
            if i % 2 == 0:  # Node
                node_id = path[i]
                node_type = G.nodes[node_id]['node_type']
                meta_path.append(node_type)
            else:  # Relation
                meta_path.append(path[i])

        meta_path = tuple(meta_path)

        # Add the path to the list of paths for the corresponding meta path
        if meta_path not in meta_paths_dict:
            meta_paths_dict[meta_path] = []
        meta_paths_dict[meta_path].append(path)

    return meta_paths_dict

def calculate_relation_averages(G, layer_only = False):
    relation_sums = {}
    relation_counts = {}

    # Iterate over all edges in the graph
    for u, v, data in tqdm(G.edges(data=True)):
        relation = data['relation']
        if layer_only:
            weight = data['layer' + str(layer_only) + '_att']
        else:
            weight = data['layer1_att'] + data['layer2_att']
        
        # Summing weights and counting occurrences for each relation
        if relation in relation_sums:
            relation_sums[relation] += weight
            relation_counts[relation] += 1
        else:
            relation_sums[relation] = weight
            relation_counts[relation] = 1

    # Calculating averages
    relation_averages = {rel: relation_sums[rel] / relation_counts[rel] for rel in relation_sums}
    return relation_averages

# %%
def find_meta_paths(X_id, Y_id, G, not_cool_rel, relation_averages, enrichment = True):
    neighborhood_X = get_two_hop_neighborhood_enrichment_per_relation(G, X_id, K, K2, relation_averages, enrichment)
    neighborhood_Y = get_two_hop_neighborhood_enrichment_per_relation(G, Y_id, K, K2, relation_averages, enrichment)
    common_neighborhood = neighborhood_X.union(neighborhood_Y)
    subG = G.subgraph(common_neighborhood)
    #print('Number of neighbors: ', len(subG))
    paths = find_relation_specific_paths(subG, X_id, Y_id, max_depth=4)
    path_scores_enrichment = [score_path_enrichment(G, path, relation_averages, enrichment) for path in paths]
    meta_paths_dict = group_paths_by_meta_paths_with_node_types(paths, G)
    meta_paths = list(meta_paths_dict.keys())
    valid_meta_paths = [i for i in meta_paths if len(np.intersect1d(not_cool_rel, i)) == 0]
    return paths, path_scores_enrichment, meta_paths_dict, meta_paths, valid_meta_paths

# %%
res.keys()
# Out:
# dict_keys(['prediction', 'label', 'result'])

# %%
import sys
sys.path.append('../')
from txgnn import TxData
txdata = TxData(data_folder_path = '../data')
txdata.prepare_split(split = 'random', seed = 1)
# Out:
# Found local copy...
# Found local copy...
# Found local copy...
# Found saved processed KG... Loading...
# Splits detected... Loading splits....
#   6%|█████▌                                                                                             | 50.3M/888M [00:16<01:47, 7.82MiB/s]
# Creating DGL graph....
# Done!

# %%
mapping = txdata.retrieve_id_mapping()
idx2id_disease = mapping['idx2id_disease'] 
idx2id_drug = mapping['idx2id_drug'] 
id2name_disease = mapping['id2name_disease'] 
id2name_drug = mapping['id2name_drug']
id2idx_disease = {j:i for i,j in idx2id_disease.items()}

# %%
import pickle
with open('name_mapping.pkl', 'wb') as f: 
    pickle.dump(mapping, f)

# %%
## for each relation, get the top K nodes.
K = 10 ## top K first hop neighbors
K2 = 10 ## top K2 second hop neighbors

# %%
## build a graph using either d_att, d_gm, d_ge
G_att = build_graph(d_att)
G_gm = build_graph(d_gm)
G_ge = build_graph(d_ge)

## to calculate average weight per relation for enrichment calculation
relation_averages_att = calculate_relation_averages(G_att)
relation_averages_gm = calculate_relation_averages(G_gm)
relation_averages_ge = calculate_relation_averages(G_ge)
# Out:
# 7676670it [07:53, 16214.33it/s]
# 7676670it [07:55, 16133.04it/s]
# 7676670it [07:59, 15993.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 7676670/7676670 [00:07<00:00, 960340.24it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 7676670/7676670 [00:08<00:00, 948166.28it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 7676670/7676670 [00:07<00:00, 977170.29it/s]

# %%
G_dict = {
    'att': G_att,
    'gm': G_gm,
    'ge': G_ge
}

relation_avg_dict = {
    'att': relation_averages_att,
    'gm': relation_averages_gm,
    'ge': relation_averages_ge
}

# %%
# query disease name
X_id = 'macular degeneration'
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
# top 20 diseases with many connections to the graph but zero indications
# top 20 diseases with few indications (ranked by accuracy)
# 10 diseases with recently approved therapies (which means lots of interest in these diseases)

# %%
result[result.Name == 'macular degeneration']['Hits@50'].values
# Out:
# array([list(['Lutein', 'Verteporfin', 'Ranibizumab', 'Pegaptanib', 'Anecortave acetate', 'Aflibercept', 'Brolucizumab'])],
#       dtype=object)

# %%
truth = result[result.Name == X_id]['Hits@100'].values[0] + result[result.Name == X_id]['Missed@100'].values[0]

# %%
## given a disease, find the most promising drugs that are not approved. or pick your fav drugs

ranked_list = result[result.Name == X_id]['Ranked List'][0]
difference = np.setdiff1d(ranked_list, truth)
ordered_difference = np.array([item for item in ranked_list if item in difference])
Y_id = ordered_difference[0]
print(Y_id)
# Out:
# Polidocanol

# %%
Y_id = id2name_drug['DB15303']
Y_id
# Out:
# 'Faricimab'

# %%
## filtering not-that-interesting meta paths?
# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
sigmoid(res['prediction']['1.0']['DB00002'])
# Out:
# 0.009866393590457347

# %%
all_path = pd.DataFrame()
G = G_dict['gm']
enrichment = False
def get_path(X_id, Y_id, G, not_cool_rel, enrichment, label):
    try:
        path = find_meta_paths(X_id, Y_id, G, not_cool_rel, relation_avg_dict['gm'], enrichment = enrichment)
        to_save = []
        for meta_path, paths in path[2].items():
            if meta_path in path[-1]:
                path_scores = [score_path_enrichment(G, path, relation_avg_dict['gm'], enrichment) for path in paths]
                to_save += tuple(zip([X_id]* len(path_scores), 
                                     [Y_id]* len(path_scores), 
                                     [print_beautiful_path(meta_path)] * len(path_scores), 
                                     print_beautiful_paths(paths), 
                                     path_scores, 
                                     [sigmoid(res['prediction'][name2id_disease[X_id]][name2id_drug[Y_id]])] * len(path_scores)))
        out =  pd.DataFrame(to_save).rename(columns = {0: 'Disease', 1: 'Drug', 2: 'Meta-Path', 3: 'Path', 4: 'Path Score', 5: 'Prediction Score'})
        out['Category'] = label
        return out
    except:
        print('Error: ', X_id, ' ', Y_id)

# %%
# 10 disease-drug pairs with recently approved therapies

# %%
approve_diseases = ['von Hippel-Lindau disease', 'atopic dermatitis', 'familial hypercholesterolemia', \
                     'asthma', 'cytomegalovirus infection', 'acquired polycythemia vera', \
                     'psoriasis', 'type 2 diabetes mellitus', 'CDKL5 disorder', \
                     'myelofibrosis', 'macular degeneration']
s = """DB15463
DB12169
DB14901
DB15090
DB06234
DB15119
DB06083
DB15171
DB05087
DB11697
DB15303"""
fda_drugs = s.split('\n')
approve_drugs = [id2name_drug[i] for i in fda_drugs]

# %%
disease_drug_pairs = tuple(zip(approve_diseases, approve_drugs, ['Approved Pairs'] * len(approve_diseases)))

# %%
def get_path_wrapper(X):
    return get_path(X[0], X[1], G, not_cool_rel, enrichment, label = X[2])

# %%
all_path = pd.DataFrame()
for i in r:
    all_path = all_path.append(i)

# %%
all_path
# Out:
#                        Disease       Drug  \
# 0    von Hippel-Lindau disease     PT2977
# 1    von Hippel-Lindau disease     PT2977
# 2    von Hippel-Lindau disease     PT2977
# 3    von Hippel-Lindau disease     PT2977
# 4    von Hippel-Lindau disease     PT2977
# ..                         ...        ...
# 707       macular degeneration  Faricimab
# 708       macular degeneration  Faricimab
# 709       macular degeneration  Faricimab
# 710       macular degeneration  Faricimab
# 711       macular degeneration  Faricimab
#
#                                              Meta-Path  \
# 0    disease -> disease_phenotype_positive -> effec...
# 1    disease -> disease_phenotype_positive -> effec...
# 2    disease -> disease_phenotype_positive -> effec...
# 3    disease -> disease_phenotype_positive -> effec...
# 4    disease -> disease_protein -> gene/protein -> ...
# ..                                                 ...
# 707  disease -> indication -> drug -> drug_protein ...
# 708  disease -> indication -> drug -> drug_protein ...
# 709  disease -> indication -> drug -> drug_protein ...
# 710  disease -> indication -> drug -> drug_protein ...
# 711  disease -> indication -> drug -> indication ->...
#
#                                                   Path  Path Score  \
# 0    von Hippel-Lindau disease -> disease_phenotype...    0.174054
# 1    von Hippel-Lindau disease -> disease_phenotype...    0.188529
# 2    von Hippel-Lindau disease -> disease_phenotype...    0.162783
# 3    von Hippel-Lindau disease -> disease_phenotype...    0.156913
# 4    von Hippel-Lindau disease -> disease_protein -...    0.139921
# ..                                                 ...         ...
# 707  macular degeneration -> indication -> Pegaptan...    0.503949
# 708  macular degeneration -> indication -> Broluciz...    0.591097
# 709  macular degeneration -> indication -> Pegaptan...    0.678410
# 710  macular degeneration -> indication -> Broluciz...    0.794607
# 711  macular degeneration -> indication -> Lutein -...    0.923684
#
#      Prediction Score        Category
# 0            0.711052  Approved Pairs
# 1            0.711052  Approved Pairs
# 2            0.711052  Approved Pairs
# 3            0.711052  Approved Pairs
# 4            0.711052  Approved Pairs
# ..                ...             ...
# 707          0.432673  Approved Pairs
# 708          0.432673  Approved Pairs
# 709          0.432673  Approved Pairs
# 710          0.432673  Approved Pairs
# 711          0.432673  Approved Pairs
#
# [2372 rows x 7 columns]

# %%
# 10 diseases with recent approvals and get their top 20 drugs for pairs

# %%
disease_drug_pairs = list(disease_drug_pairs)

# %%
label = 'Recent Approved Diseases'
for disease in approve_diseases:
    ranked_list = result[result.Name == disease]['Ranked List'][0]
    difference = np.setdiff1d(ranked_list, truth)
    ordered_difference = np.array([item for item in ranked_list if item in difference])
    Y_ids = ordered_difference[:5]
    disease_drug_pairs+=list(zip([disease] * 5, Y_ids, [label] * 5))

# %%
# top 20 diseases with many connections to the graph but zero indications
# top 20 diseases with few indications (ranked by accuracy)

# %%
result['number_of_indications'] = result.Labels.apply(lambda x: sum(x.values()))

# %%
disease_id_to_num_of_neighbors = dict(txdata.df[txdata.df.x_type == 'disease'].groupby('x_id').y_id.agg(len))

# %%
result['number_of_neighbors'] = result.ID.apply(lambda x: disease_id_to_num_of_neighbors[x] if x in disease_id_to_num_of_neighbors else 0)

# %%
result.number_of_neighbors.value_counts()
# Out:
# 0      5966
# 1      1300
# 2      1263
# 3       914
# 4       747
#        ...
# 169       1
# 162       1
# 363       1
# 347       1
# 150       1
# Name: number_of_neighbors, Length: 190, dtype: int64

# %%
## pick 10 diseases in each disease area, 5 with 0 indication, 5 with 1 indication,

# %%
for area in ['cell_proliferation', 'mental_health', 'cardiovascular', 'anemia', 'adrenal_gland','autoimmune', 'metabolic_disorder', 'diabetes', 'neurodigenerative']:
    ind_diseases_test = pd.read_csv('../data/disease_files/' + area + '.csv').node_id.values
    disease_in_the_area = [id2name_disease[idx2id_disease[i]] for i in ind_diseases_test if i in idx2id_disease]
    ## diseases with a few indications
    disease_few_indications = result[result.Name.isin(disease_in_the_area) & (result.number_of_indications >= 1) & (result.number_of_indications < 5) & (result.number_of_neighbors != 0)].Name.values[:3]
    label = area + '-disease-few-indications-top3'
    for disease in disease_few_indications:
        ranked_list = result[result.Name == disease]['Ranked List'][0]
        difference = np.setdiff1d(ranked_list, truth)
        ordered_difference = np.array([item for item in ranked_list if item in difference])
        Y_ids = ordered_difference[:5]
        disease_drug_pairs+=list(zip([disease] * 5, Y_ids, [label] * 5))

    ## diseases with zero indications but many neighbors
    disease_zero_indications_many_neighbors = result[result.Name.isin(disease_in_the_area) & (result.number_of_indications == 0) & (result.number_of_neighbors != 0)].sort_values('number_of_neighbors')[::-1].Name.values[:3]
    
    label = area + '-disease-zero-indications-top3-num-neighbors'
    for disease in disease_zero_indications_many_neighbors:
        ranked_list = result[result.Name == disease]['Ranked List'][0]
        difference = np.setdiff1d(ranked_list, truth)
        ordered_difference = np.array([item for item in ranked_list if item in difference])
        Y_ids = ordered_difference[:5]
        disease_drug_pairs+=list(zip([disease] * 5, Y_ids, [label] * 5))

# %%
len(disease_drug_pairs)
# Out:
# 276

# %%
import multiprocessing
with multiprocessing.Pool(30) as p:
    r = list(tqdm(p.imap(get_path_wrapper, disease_drug_pairs), total=len(disease_drug_pairs)))
# Out:
#   0%|                                                                                                                | 0/276 [00:00<?, ?it/s]
#   0%|▍                                                                                                       | 1/276 [00:00<04:05,  1.12it/s]
#   1%|█▏                                                                                                      | 3/276 [00:19<32:20,  7.11s/it]
#   1%|█▍                                                                                                    | 4/276 [04:01<6:09:24, 81.49s/it]
# Error:  hereditary continuous muscle fiber activity   Furazidin
# Error:  hereditary continuous muscle fiber activity   Monoxerutin
# Error:  trichothiodystrophy   Monoxerutin
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 276/276 [33:15<00:00,  7.23s/it]

# %%
all_path = pd.DataFrame()
for i in r:
    all_path = all_path.append(i)

# %%
all_path.reset_index(drop = True).to_csv('path_viz.csv', index = False)

# %%
def parse_genes(x):
    idx_gene = []
    for idx, i in enumerate(x['Meta-Path'].split('->')):
        if i.strip() == 'gene/protein':
            idx_gene.append(idx)
    return [x['Path'].split('->')[gene].strip() for gene in idx_gene]

# %%
tqdm.pandas()
all_path['genes'] = all_path.progress_apply(lambda x: parse_genes(x), axis = 1)
# Out:
#   0%|                                                                                                             | 0/335752 [00:00<?, ?it/s]
#   1%|▉                                                                                              | 3466/335752 [00:00<00:09, 34659.21it/s]
#   4%|███▍                                                                                          | 12194/335752 [00:00<00:04, 65607.85it/s]
#   6%|█████▉                                                                                        | 21163/335752 [00:00<00:04, 76602.84it/s]
#   9%|████████▎                                                                                     | 29499/335752 [00:00<00:03, 79269.09it/s]
#  11%|██████████▌                                                                                   | 37796/335752 [00:00<00:03, 80602.96it/s]
#  14%|█████████████▍                                                                                | 47801/335752 [00:00<00:03, 87213.33it/s]
#  18%|████████████████▊                                                                             | 60187/335752 [00:00<00:02, 99191.97it/s]
#  21%|███████████████████▋                                                                          | 70107/335752 [00:00<00:02, 98813.12it/s]
#  24%|██████████████████████▍                                                                       | 79989/335752 [00:00<00:02, 94900.33it/s]
#  27%|█████████████████████████                                                                     | 89510/335752 [00:01<00:02, 94753.88it/s]
#  29%|███████████████████████████▋                                                                  | 99007/335752 [00:01<00:02, 93107.62it/s]
#  32%|██████████████████████████████                                                               | 108336/335752 [00:01<00:02, 91970.05it/s]
#  36%|█████████████████████████████████▌                                                          | 122316/335752 [00:01<00:02, 106041.82it/s]
#  40%|████████████████████████████████████▋                                                       | 133748/335752 [00:01<00:01, 108488.44it/s]
#  43%|███████████████████████████████████████▉                                                    | 145569/335752 [00:01<00:01, 111375.12it/s]
#  47%|██████████████████████████████████████████▉                                                 | 156739/335752 [00:01<00:01, 107850.63it/s]
#  50%|█████████████████████████████████████████████▉                                              | 167569/335752 [00:01<00:01, 105030.73it/s]
#  53%|████████████████████████████████████████████████▊                                           | 178113/335752 [00:01<00:01, 103388.82it/s]
#  56%|███████████████████████████████████████████████████▋                                        | 188480/335752 [00:01<00:01, 101157.71it/s]
#  60%|███████████████████████████████████████████████████████                                     | 200861/335752 [00:02<00:01, 107659.59it/s]
#  63%|██████████████████████████████████████████████████████████▍                                 | 213058/335752 [00:02<00:01, 111820.14it/s]
#  67%|█████████████████████████████████████████████████████████████▊                              | 225652/335752 [00:02<00:00, 115962.39it/s]
#  71%|█████████████████████████████████████████████████████████████████                           | 237290/335752 [00:02<00:00, 105125.09it/s]
#  74%|████████████████████████████████████████████████████████████████████▍                       | 249885/335752 [00:02<00:00, 110882.01it/s]
#  78%|████████████████████████████████████████████████████████████████████████▏                   | 263418/335752 [00:02<00:00, 117804.02it/s]
#  82%|███████████████████████████████████████████████████████████████████████████▍                | 275379/335752 [00:02<00:00, 116503.80it/s]
#  86%|███████████████████████████████████████████████████████████████████████████████▏            | 289074/335752 [00:02<00:00, 122397.84it/s]
#  90%|███████████████████████████████████████████████████████████████████████████████████         | 302958/335752 [00:02<00:00, 127192.47it/s]
#  95%|███████████████████████████████████████████████████████████████████████████████████████     | 317725/335752 [00:03<00:00, 133215.49it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 335752/335752 [00:03<00:00, 101377.26it/s]

# %%
gene_count_per_path = {}
for gene in tqdm(all_path.genes):
    for i in gene:
        if i in gene_count_per_path:
            gene_count_per_path[i] += 1
        else:
            gene_count_per_path[i] = 1
# Out:
#   0%|                                                                                                             | 0/335752 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 335752/335752 [00:00<00:00, 1785299.41it/s]

# %%
gene_count_per_path
# Out:
# {'EPAS1': 57,
#  'CCND1': 440,
#  'VHL': 498,
#  'STAT5A': 25,
#  'UBC': 1086,
#  'EGLN3': 11,
#  'NEDD8': 6,
#  'PIM1': 10,
#  'PSMC3': 1,
#  'PCSK9': 772,
#  'ABCA1': 1317,
#  'APOA2': 393,
#  'APOB': 536,
#  'APOC3': 392,
#  'APOE': 1609,
#  'CETP': 651,
#  'HMGCR': 2783,
#  'LIPC': 539,
#  'LPL': 1184,
#  'PON1': 444,
#  'PON2': 1112,
#  'SREBF2': 1282,
#  'LDLRAP1': 1040,
#  'ABCG5': 270,
#  'ABCG8': 307,
#  'GHR': 1473,
#  'PPP1R17': 181,
#  'SREBF1': 17,
#  'ARMC6': 22,
#  'HBA1': 121,
#  'HBB': 104,
#  'JAK2': 1781,
#  'IFNA2': 425,
#  'JAK1': 686,
#  'MPL': 484,
#  'SH2B3': 112,
#  'TET2': 762,
#  'GH1': 62,
#  'EGLN1': 130,
#  'SLC30A10': 53,
#  'HBA2': 9,
#  'IL6': 1443,
#  'IL12B': 777,
#  'IL23A': 721,
#  'IL6R': 44,
#  'IL6ST': 19,
#  'IL2': 136,
#  'CXCL8': 447,
#  'RUNX3': 962,
#  'HLA-C': 1377,
#  'MKI67': 948,
#  'NOS2': 2490,
#  'REN': 518,
#  'TYK2': 1527,
#  'VNN2': 860,
#  'TRAF3IP2': 1150,
#  'IL36RN': 265,
#  'VNN3': 279,
#  'CARD14': 792,
#  'LCE3D': 225,
#  'TAGAP': 781,
#  'ZNF816': 581,
#  'NFKB1': 37,
#  'TCF7': 23,
#  'HDAC1': 455,
#  'IRF1': 8,
#  'POLR2A': 2,
#  'TBP': 858,
#  'CREBBP': 93,
#  'RELB': 2,
#  'NCOR2': 13,
#  'NR3C1': 7214,
#  'ARMC8': 76,
#  'PKP3': 27,
#  'PKP2': 47,
#  'RAP1GDS1': 75,
#  'ANKAR': 79,
#  'ARVCF': 48,
#  'FOS': 30,
#  'CTNND1': 70,
#  'ETS1': 124,
#  'AR': 1879,
#  'IRF5': 57,
#  'GABRA1': 901,
#  'GABRA4': 261,
#  'GABRB3': 464,
#  'GABRA6': 79,
#  'GABRA2': 496,
#  'GABRA3': 498,
#  'VEGFA': 485,
#  'ANGPT2': 330,
#  'C2': 57,
#  'CFH': 103,
#  'CFI': 88,
#  'HTRA1': 114,
#  'RLBP1': 33,
#  'RPGR': 114,
#  'SQSTM1': 133,
#  'FBLN5': 102,
#  'CFHR4': 6,
#  'NMNAT1': 93,
#  'RAX2': 35,
#  'FGD6': 84,
#  'CTNNB1': 45,
#  'PDGFRB': 150,
#  'GLUL': 105,
#  'BCHE': 912,
#  'THRA': 712,
#  'UGT1A1': 723,
#  'ABCB1': 13122,
#  'SLCO1B3': 1025,
#  'SLCO1C1': 560,
#  'SLC7A5': 804,
#  'ALB': 8091,
#  'SERPINA7': 185,
#  'SLCO4A1': 613,
#  'SLC10A1': 413,
#  'SLCO4C1': 314,
#  'THRB': 63,
#  'ESR2': 4,
#  'PTGS2': 825,
#  'AVP': 12,
#  'KNG1': 307,
#  'TRH': 19,
#  'GSK3B': 24,
#  'ESR1': 543,
#  'TCF4': 14,
#  'STAT3': 39,
#  'ABCG2': 4024,
#  'CRYAB': 4,
#  'HIF1A': 2,
#  'HRH1': 41,
#  'FLG': 65,
#  'CCR3': 1,
#  'CCR5': 3,
#  'IL13': 55,
#  'PPARA': 571,
#  'S100A8': 1,
#  'CCL5': 1,
#  'CCL22': 1,
#  'EMSY': 1,
#  'IL33': 1,
#  'KCNH2': 26,
#  'IL4': 743,
#  'GCG': 8,
#  'UGT2B7': 611,
#  'ITGAL': 564,
#  'ABCB11': 864,
#  'SLCO1B1': 714,
#  'UGT1A3': 356,
#  'PRKACA': 6,
#  'FLOT1': 5,
#  'FOXA2': 12,
#  'EP300': 33,
#  'FOXA1': 14,
#  'DERL1': 1,
#  'LGALS3': 151,
#  'PPARGC1A': 83,
#  'LGALS9': 2,
#  'VCP': 11,
#  'TP53': 823,
#  'ERLIN2': 2,
#  'NR1H4': 8,
#  'NR4A1': 2,
#  'MVK': 22,
#  'ADRB3': 432,
#  'APC': 6,
#  'IRS1': 14,
#  'LEPR': 216,
#  'NEIL1': 2,
#  'PPARGC1B': 3,
#  'MMP25': 499,
#  'CES1': 635,
#  'NR1I2': 903,
#  'AKR1B1': 553,
#  'AKR1C3': 459,
#  'AKR1C2': 289,
#  'AKR1C1': 363,
#  'UGT1A9': 538,
#  'CBR1': 851,
#  'NR1H2': 1,
#  'CREB3': 2,
#  'PDZK1IP1': 1,
#  'PITX3': 12,
#  'LRP2': 7,
#  'EGFR': 50,
#  'LUC7L2': 1,
#  'CLU': 14,
#  'RBCK1': 3,
#  'MAPK3': 3,
#  'CREB1': 1,
#  'HOXC8': 1,
#  'MMP2': 9,
#  'GRB2': 58,
#  'PTPN3': 1,
#  'YBX1': 15,
#  'APOA1': 10,
#  'ADRB2': 3769,
#  'C9': 7,
#  'ANXA2': 1,
#  'NOS3': 4,
#  'APOA5': 4,
#  'HDAC2': 986,
#  'SLCO2B1': 915,
#  'ABCC2': 601,
#  'SLC15A1': 419,
#  'SORT1': 2,
#  'HNF4G': 4,
#  'HNF4A': 6,
#  'JUND': 6,
#  'EWSR1': 5,
#  'SFXN5': 1,
#  'RDH13': 1,
#  'SLC25A1': 491,
#  'ABCC3': 679,
#  'UGT2B15': 452,
#  'ANPEP': 563,
#  'NPC1L1': 171,
#  'CTCF': 4,
#  'CEBPB': 4,
#  'FOSL2': 2,
#  'PARP1': 854,
#  'ALOX5': 545,
#  'CAT': 63,
#  'DNMT1': 938,
#  'HLA-DQA1': 647,
#  'HLA-DQB1': 689,
#  'HSD11B2': 1531,
#  'IL1B': 902,
#  'MMP9': 659,
#  'MUC7': 135,
#  'NPY': 279,
#  'PDE4D': 765,
#  'PLAU': 678,
#  'PTEN': 1453,
#  'TIMP3': 689,
#  'GSDMB': 556,
#  'TSLP': 297,
#  'ORMDL3': 662,
#  'TGFB1': 839,
#  'TNF': 1680,
#  'IL1RN': 506,
#  'ADRB1': 1650,
#  'SLC22A5': 1888,
#  'SLC22A1': 1116,
#  'SLC22A3': 1459,
#  'SLC22A4': 1072,
#  'UGT1A4': 143,
#  'UGT1A8': 115,
#  'NGF': 413,
#  'PTGS1': 1423,
#  'JUN': 349,
#  'ARRDC3': 1,
#  'SRC': 23,
#  'SLC9A3R1': 12,
#  'SLC9A3R2': 6,
#  'ARRB1': 10,
#  'SH3GL2': 2,
#  'CD4': 6,
#  'CDK15': 2,
#  'GTF2B': 8,
#  'ABL1': 170,
#  'MAGI2': 3,
#  'PRNP': 2,
#  'IL7R': 3,
#  'SPTLC1': 2,
#  'EEF1A1': 25,
#  'TGFB2': 5,
#  'TGFBR2': 2,
#  'TGFBR1': 2,
#  'SMAD3': 2,
#  'SERPINA1': 6,
#  'COMT': 12,
#  'INS': 14,
#  'KCNJ8': 8,
#  'HCRT': 4,
#  'COL4A1': 1,
#  'PLAT': 133,
#  'AGT': 17,
#  'AGER': 2,
#  'PLCB1': 2,
#  'ACE': 5,
#  'ACHE': 254,
#  'CRH': 39,
#  'DDT': 643,
#  'ADRA2A': 1188,
#  'CHRM4': 2,
#  'GSTP1': 287,
#  'ORM1': 483,
#  'SLC22A2': 571,
#  'ORM2': 291,
#  'SUMO2': 11,
#  'IMMT': 1,
#  'PTGDS': 1,
#  'PRDX6': 1,
#  'SERPINE1': 8,
#  'MMP1': 120,
#  'PGR': 539,
#  'PLA2G4A': 24,
#  'PRKCA': 440,
#  'SERPINA6': 1168,
#  'NR3C2': 820,
#  'BMI1': 1,
#  'RELA': 14,
#  'CDKN1A': 17,
#  'IL10': 4,
#  'BRCA1': 59,
#  'KAT2B': 5,
#  'ARMC7': 16,
#  'IRF8': 2,
#  'LAMA5': 1,
#  'PRDM14': 8,
#  'PBX1': 1,
#  'ERBB2': 65,
#  'ACVRL1': 1,
#  'HSP90AA1': 6,
#  'RNF2': 18,
#  'NLRP3': 3,
#  'FTH1': 1,
#  'ACP1': 1,
#  'ADRA1B': 484,
#  'NR0B1': 349,
#  'SLC22A8': 1193,
#  'BAX': 4,
#  'RUNX1': 8,
#  'CSF2': 194,
#  'CSF3': 128,
#  'ETV6': 1,
#  'MTHFR': 41,
#  'GAP43': 5,
#  'RELN': 5,
#  'GAL': 6,
#  'NRSN1': 5,
#  'ITGB3': 2,
#  'PEPD': 1,
#  'PLCG1': 1,
#  'CHEK2': 12,
#  'NFKBIA': 4,
#  'SOCS1': 32,
#  'HES1': 9,
#  'SPRY2': 2,
#  'CDKN2A': 27,
#  'KRAS': 586,
#  'TAL1': 17,
#  'HAVCR2': 8,
#  'CD274': 6,
#  'SYK': 4,
#  'CSF3R': 1,
#  'ZBTB16': 1,
#  'SMARCA4': 660,
#  'GATA1': 42,
#  'PTPN6': 19,
#  'TSHR': 5,
#  'SHC1': 15,
#  'GATA2': 64,
#  'EZH2': 8,
#  'LTF': 2,
#  'SLC5A6': 11,
#  'OXT': 76,
#  'SOD2': 737,
#  'IL23R': 71,
#  'HCAR2': 16,
#  'HLA-B': 21,
#  'CD14': 14,
#  'SHBG': 1414,
#  'ANXA1': 1810,
#  'ZFP36': 15,
#  'SLCO1A2': 1886,
#  'NOTCH1': 8,
#  'RPL10': 4,
#  'TNFSF9': 28,
#  'SPI1': 41,
#  'DDIT3': 6,
#  'HSPA5': 5,
#  'CALR': 762,
#  'GRAMD1A': 5,
#  'CENPB': 5,
#  'FPGS': 7,
#  'ABCC4': 189,
#  'HSD11B1': 1913,
#  'CRP': 330,
#  'PPARG': 1531,
#  'CARM1': 418,
#  'RPL23': 15,
#  'C1QA': 10,
#  'RPL15': 7,
#  'JAZF1': 2,
#  'MUC1': 1,
#  'BIRC3': 2,
#  'TNFRSF13B': 1,
#  'AURKB': 4,
#  'CALM2': 5,
#  'NCOR1': 3,
#  'NRIP1': 4,
#  'NR0B2': 5,
#  'CD36': 2,
#  'RNF31': 1,
#  'TNIP2': 1,
#  'NFATC4': 2,
#  'TRIM37': 3,
#  'NFE2L2': 4,
#  'RNF13': 2,
#  'IFNB1': 2,
#  'SRD5A2': 554,
#  'AKR1D1': 93,
#  'HMOX1': 124,
#  'SIRT1': 1,
#  'CYSRT1': 3,
#  'PTTG1': 140,
#  'TNIP1': 199,
#  'EGF': 2,
#  'FCGR2A': 4,
#  'IL12A': 1,
#  'GP1BB': 6,
#  'CAPN10': 167,
#  'HP': 222,
#  'PAX4': 44,
#  'ABCC8': 585,
#  'HNF1A': 9,
#  'IFNG': 152,
#  'CASP3': 35,
#  'CASP8': 37,
#  'DPP4': 400,
#  'INSR': 677,
#  'IRS2': 199,
#  'RETN': 52,
#  'ATP2A2': 236,
#  'CPT1A': 38,
#  'ICAM1': 219,
#  'SMAD5': 180,
#  'NEUROD1': 102,
#  'ENPP1': 162,
#  'RNF6': 166,
#  'MIRLET7D': 143,
#  'MIR1307': 41,
#  'MIR3173': 11,
#  'TNFRSF10A': 2,
#  'MIR222': 43,
#  'MIR375': 11,
#  'MIR1260B': 17,
#  'BCL10': 1,
#  'CCL11': 1,
#  'GPT': 8,
#  'IGF1': 8,
#  'AIFM1': 8,
#  'FOXP3': 283,
#  'SLC29A3': 2,
#  'CAV1': 4,
#  'HK1': 142,
#  'LEP': 88,
#  'MAOB': 680,
#  'PRKAA2': 2,
#  'MC4R': 89,
#  'EDN1': 182,
#  'SNX27': 2,
#  'MZT2B': 1,
#  'PIN1': 1,
#  'HTT': 7,
#  'NFYB': 3,
#  'STAT6': 2,
#  'B2M': 3,
#  'AMBP': 1,
#  'GSR': 1,
#  'MAOA': 1232,
#  'KCNJ11': 590,
#  'HMGA1': 74,
#  'KCNJ1': 202,
#  'CFTR': 2,
#  'F2RL1': 3,
#  'H3C13': 1,
#  'GLI3': 1,
#  'GLI1': 1,
#  'CAMK2A': 2,
#  'GABRG2': 730,
#  'CACNA1A': 2,
#  'HCN1': 13,
#  'TBCD': 19,
#  'DRD2': 47,
#  'HTR1A': 35,
#  'HTR1B': 6,
#  'CAMK2G': 1,
#  'GNAO1': 3,
#  'WDR45': 8,
#  'PNKP': 7,
#  'HTR2A': 2,
#  'HTR1D': 1,
#  'PRF1': 1,
#  'FMO3': 85,
#  'SLC47A1': 610,
#  'FLT3': 75,
#  'SLC47A2': 66,
#  'POU2F2': 108,
#  'PRKCD': 341,
#  'SNCA': 2,
#  'SEMG1': 1,
#  'YWHAG': 3,
#  'KIT': 1158,
#  'DDR1': 118,
#  'PDGFRA': 144,
#  'BCR': 148,
#  'HSP90B1': 1,
#  'STAT5B': 3,
#  'YWHAH': 1,
#  'MGP': 1,
#  'MC2R': 55,
#  'MC5R': 29,
#  'MC1R': 326,
#  'MC3R': 21,
#  'GRIA1': 1,
#  'MTOR': 2,
#  'ITPA': 1,
#  'CHRM1': 2,
#  'CACNA1D': 2,
#  'FMO1': 2,
#  'PAH': 335,
#  'QDPR': 2,
#  'GAMT': 1,
#  'TPH1': 7,
#  'TH': 18,
#  'DGAT2': 14,
#  'SLC5A8': 5,
#  'XDH': 154,
#  'SLC22A7': 779,
#  'AOX1': 19,
#  'COX7B': 12,
#  'COX5B': 13,
#  'COX4I1': 14,
#  'PLA2G1B': 5,
#  'COX6A2': 6,
#  'COX8A': 13,
#  'COX5A': 13,
#  'COX6C': 12,
#  'MT-CO2': 4,
#  'ADH1C': 6,
#  'MT-CO1': 6,
#  'GPBAR1': 4,
#  'ALDH2': 1765,
#  'CHAT': 85,
#  'NPR1': 901,
#  'CHRNA1': 102,
#  'CHRNB1': 272,
#  'CHRND': 75,
#  'CHRNE': 172,
#  'DPAGT1': 526,
#  'GFPT1': 472,
#  'LRP4': 419,
#  'SCN4A': 223,
#  'SNAP25': 376,
#  'COLQ': 346,
#  'PREPL': 480,
#  'GMPPB': 446,
#  'ALG14': 382,
#  'AK9': 377,
#  'MYO9A': 489,
#  'PRKCE': 3,
#  'RAD21': 1,
#  'SRD5A1': 532,
#  'SUZ12': 1,
#  'MAX': 7,
#  'MYC': 80,
#  'TRIM68': 1,
#  'RHOA': 2,
#  'PEA15': 1,
#  'HDAC3': 1,
#  'PTGIR': 339,
#  'NPPA': 4,
#  'NPPB': 8,
#  'PGM1': 305,
#  'NGLY1': 287,
#  'HSPB2': 1,
#  'OPRM1': 73,
#  'P4HTM': 13,
#  'CNR1': 7,
#  'TAC1': 1,
#  'VIP': 7,
#  'TRPV1': 1,
#  'GABRA5': 253,
#  'UBQLN1': 6,
#  'ADRA1A': 760,
#  'ADRA2C': 1022,
#  'DRD1': 372,
#  'ADRA2B': 520,
#  'ADRA1D': 483,
#  'AP2M1': 7,
#  'EIF3F': 11,
#  'PAK1': 2,
#  'ABCC1': 1188,
#  'ASPG': 10,
#  'SLC22A11': 143,
#  'SLC22A6': 403,
#  'HRH2': 28,
#  'SLC19A1': 8,
#  'DHFR': 26,
#  'POMC': 25,
#  'ACAN': 777,
#  'CA1': 606,
#  'MDM4': 1045,
#  'OVGP1': 826,
#  'IL27RA': 828,
#  'TMPRSS3': 633,
#  'HS3ST6': 130,
#  'TICAM1': 934,
#  'H3-4': 157,
#  'HLA-DRB1': 31,
#  'MMP8': 10,
#  'PTK2': 15,
#  'CSK': 6,
#  'CBX7': 1,
#  'KIAA0319L': 6,
#  'TLR5': 7,
#  'MAPK6': 4,
#  'UPF3A': 4,
#  'KPNA6': 7,
#  'RPS6KA5': 6,
#  'JPH2': 5,
#  'PRKCZ': 3,
#  'VRK1': 1,
#  'TMX4': 3,
#  'IL27': 5,
#  'B4GALT1': 5,
#  'HGF': 20,
#  'PDPK1': 2,
#  'TRAF5': 2,
#  'PIK3CA': 1304,
#  'EBF1': 2,
#  'AIRE': 2,
#  'KAT2A': 1,
#  'CTBP1': 3,
#  'SUMO1': 3,
#  'PSMC5': 3,
#  'AQP1': 43,
#  'CA2': 70,
#  'CA4': 43,
#  'CA3': 34,
#  'CA7': 15,
#  'CA12': 24,
#  'CA14': 33,
#  'CCK': 13,
#  'PDYN': 25,
#  'CACNA1S': 313,
#  'RYR1': 455,
#  'REL': 5,
#  'PPP2CA': 2,
#  'CALM3': 3,
#  'RYR2': 1,
#  'CBS': 17,
#  'GSS': 30,
#  'MGMT': 28,
#  'GOT2': 35,
#  'GCLM': 30,
#  'GOT1': 25,
#  'GCLC': 29,
#  'SLC16A10': 24,
#  'NFS1': 32,
#  'CTH': 34,
#  'CSAD': 28,
#  'LDHA': 18,
#  'SIRT5': 26,
#  'BST1': 23,
#  'ACSL4': 2,
#  'NSD2': 3,
#  'BSCL2': 91,
#  'CLCN4': 578,
#  'RPS6KA3': 644,
#  'ZNF41': 353,
#  'IQSEC2': 545,
#  'UPF3B': 536,
#  'ZNF81': 488,
#  'PLAG1': 394,
#  'SMS': 272,
#  'HMGA2': 131,
#  'NONO': 396,
#  'PHF8': 509,
#  'NR4A2': 1,
#  'LHB': 1,
#  'AHR': 4,
#  'FLNA': 183,
#  'NEK3': 2,
#  'PPP1R9B': 4,
#  'GABRD': 755,
#  'GABRB1': 294,
#  'GABRG3': 140,
#  'FMR1': 1,
#  'GABRB2': 325,
#  'GABRQ': 139,
#  'GABRG1': 211,
#  'APP': 3,
#  'TGM1': 2,
#  'COL6A1': 326,
#  'FKTN': 406,
#  'LAMA2': 292,
#  'SELENON': 122,
#  'PRIMA1': 222,
#  'POMK': 57,
#  'DAG1': 274,
#  'CCL2': 13,
#  'RXYLT1': 32,
#  'B4GAT1': 218,
#  'TTN': 159,
#  'TCAP': 165,
#  'SGCA': 106,
#  'BVES': 139,
#  'DMD': 985,
#  'NKX2-5': 1,
#  'LUM': 167,
#  'CAPN3': 112,
#  'SGCG': 85,
#  'DYSF': 213,
#  'TRIM32': 189,
#  'POGLUT1': 178,
#  'UTRN': 1,
#  'SGTA': 3,
#  'ANKRD1': 2,
#  'CHPT1': 1,
#  'SLC6A2': 279,
#  'SLC6A3': 143,
#  'POLG': 7,
#  'RACK1': 1,
#  'RERE': 328,
#  'SKI': 333,
#  'KCNAB2': 314,
#  'PRDM16': 271,
#  'DNAJC18': 2,
#  'VIM': 229,
#  'MDFI': 2,
#  'AKT2': 1,
#  'ATG9A': 1,
#  'SOX2': 389,
#  'MCL1': 617,
#  'PRAME': 297,
#  'ZNF536': 6,
#  'ELOC': 6,
#  'CD22': 173,
#  'EEF2': 303,
#  'NF1': 583,
#  'PAX3': 184,
#  'MAML3': 458,
#  'ZNF667-AS1': 519,
#  'HNRNPD': 2,
#  'PARK7': 3,
#  'CCT3': 1,
#  'KRT18': 3,
#  'RPS6KA2': 11,
#  'MAPK10': 2,
#  'FLT4': 244,
#  'FLT1': 373,
#  'KDR': 356,
#  'MET': 5,
#  'HDAC4': 391,
#  'HDAC6': 360,
#  'IKZF1': 2,
#  'BMF': 1,
#  'MAPK1': 424,
#  'MAPK9': 3,
#  'FYN': 6,
#  'SIN3A': 18,
#  'H2AC20': 1,
#  'KDM1A': 4,
#  'ATM': 16,
#  'CEBPA': 2,
#  'RBPJ': 2,
#  'RBL1': 2,
#  'PKM': 3,
#  'SAP130': 2,
#  'CHD3': 6,
#  'UBD': 1,
#  'EFEMP2': 2,
#  'DDX17': 2,
#  'E2F4': 2,
#  'E4F1': 1,
#  'CD28': 12,
#  'ZEB1': 4,
#  'CD86': 1,
#  'PARP2': 1,
#  'IKZF3': 3,
#  'OCLN': 64,
#  'F5': 68,
#  'EGR1': 21,
#  'OLR1': 2,
#  'PLCG2': 1,
#  'TNFRSF1A': 7,
#  'C5': 48,
#  'NR5A2': 1,
#  'SOD1': 389,
#  'F13B': 23,
#  'TPSAB1': 2,
#  'CD209': 520,
#  'ABCB5': 7,
#  'TOP2A': 495,
#  'TLR2': 249,
#  'SLC15A2': 86,
#  'SLCO3A1': 231,
#  'AKT1': 1027,
#  'FGFR2': 909,
#  'SDHB': 722,
#  'SDHC': 625,
#  'SDHD': 634,
#  'SEC23B': 694,
#  'KLLN': 307,
#  'FLNC': 3,
#  'BUB1': 5,
#  'UCHL1': 3,
#  'SRPK1': 2,
#  'STK11': 1032,
#  'PIK3R1': 451,
#  'EIF4A3': 1,
#  'PIK3R3': 358,
#  'PIK3R2': 261,
#  'LMNA': 3,
#  'RNF19B': 2,
#  'CD40': 4,
#  'UBA1': 1,
#  'TAF1': 2,
#  'TIMM50': 1,
#  'SLC25A5': 3,
#  'ARHGDIA': 1,
#  'XRCC6': 1,
#  'CPSF7': 1,
#  'MS4A1': 1,
#  'MAPKAP1': 1,
#  'DLG1': 5,
#  'TMED2': 1,
#  'MTNR1B': 1,
#  'NRAS': 26,
#  'RET': 9,
#  'BRAF': 601,
#  'NCOA4': 1,
#  'RXRA': 2,
#  'RARB': 285,
#  'COL3A1': 1288,
#  'ALDH1A1': 277,
#  'RARA': 501,
#  'ALDH1A2': 215,
#  'RBP4': 264,
#  'RARRES1': 165,
#  'RSPH4A': 1,
#  'RXRG': 131,
#  'CRABP2': 221,
#  'COL1A1': 1305,
#  'OBP2A': 73,
#  'LCN1': 47,
#  'COL1A2': 1239,
#  'SLC39A13': 1204,
#  'B3GALT6': 1005,
#  'COL5A1': 1005,
#  'COL5A2': 1005,
#  'SMAD4': 1,
#  'TFAP2C': 20,
#  'COL8A2': 8,
#  'E2F1': 7,
#  'COL6A2': 1,
#  'PLA2G2A': 184,
#  'UGT2B4': 86,
#  'ASIC1': 154,
#  'DCN': 2,
#  'IGFBP3': 3,
#  'TGM2': 6,
#  'PTPN2': 5,
#  'SERPINF1': 2,
#  'SPARC': 4,
#  'LIG4': 4,
#  'E2F6': 2,
#  'COCH': 1,
#  'FGFR3': 778,
#  'HRAS': 1254,
#  'ERCC1': 831,
#  'BAP1': 1057,
#  'ATF7IP': 736,
#  'CD9': 14,
#  'ERCC4': 827,
#  'ABCC6': 414,
#  'ENTPD6': 726,
#  'NDUFS3': 300,
#  'NOS1': 196,
#  'NQO1': 323,
#  'ABCB8': 218,
#  'NDUFS2': 281,
#  'DMRT1': 137,
#  'KITLG': 696,
#  'TLR3': 228,
#  'PBX3': 2,
#  'SP2': 2,
#  'PLK1': 4,
#  'MAPRE1': 6,
#  'YY1': 3,
#  'PIK3CG': 24,
#  'IRAK2': 2,
#  'CTNNA1': 4,
#  'PTPN11': 555,
#  'CBLB': 9,
#  'CLTC': 10,
#  'TRIM29': 2,
#  'SLX4': 12,
#  'FANCA': 8,
#  'SLC22A18': 4,
#  'KLHDC10': 2,
#  'WT1': 14,
#  'MLF1': 6,
#  'RPS6KB1': 12,
#  'HDLBP': 1,
#  'ASXL1': 3,
#  'NBN': 8,
#  'EPG5': 1,
#  'EHMT2': 6,
#  'MAP3K7': 1,
#  'BMPR1A': 6,
#  'TUBB': 271,
#  'TOP2B': 4,
#  'POU5F1': 3,
#  'TUBA1A': 242,
#  'TUBD1': 218,
#  'TUBG1': 254,
#  'TUBE1': 203,
#  'NRF1': 1,
#  'RACGAP1': 1,
#  'ATG3': 1,
#  'SOCS6': 2,
#  'MARK4': 3,
#  'VBP1': 1,
#  'MTHFD2': 6,
#  'YAP1': 22,
#  'BUB1B': 1,
#  'ETV4': 1,
#  'FGFR4': 1,
#  'SOX4': 1,
#  'LIG1': 158,
#  'BLMH': 211,
#  'CDK4': 1,
#  'SLCO2A1': 206,
#  'ABCC5': 247,
#  'PTGER2': 126,
#  'PTGER1': 74,
#  'MYBPC1': 180,
#  'PTGDR2': 73,
#  'MYH3': 217,
#  'TNNI2': 169,
#  'TNNT3': 180,
#  'TPM2': 357,
#  'NALCN': 226,
#  'PIEZO2': 316,
#  'CTNNA3': 1,
#  'OXTR': 201,
#  'GNRHR': 50,
#  'GNRHR2': 75,
#  'PRLR': 267,
#  'GLTP': 150,
#  'GLT6D1': 11,
#  'ATP6V1A': 207,
#  'ATP6V1E1': 194,
#  'ATP6V0A2': 183,
#  'PTGFR': 61,
#  'OPRK1': 12,
#  'BDNF': 12,
#  'KIAA2013': 1,
#  'PTGER3': 73,
#  'KCNK3': 52,
#  'KCNK9': 33,
#  'S100A10': 1,
#  'MECP2': 16,
#  'BMPER': 151,
#  'IGF1R': 282,
#  'MAPT': 29,
#  'SLC23A1': 2,
#  'IFT80': 2,
#  'MGME1': 7,
#  'OPRD1': 10,
#  'OPRL1': 16,
#  'CHRNB4': 10,
#  'CHRNA3': 16,
#  'KCNA1': 222,
#  'GRIN2A': 43,
#  'CHRNA4': 32,
#  'GRIN2B': 40,
#  'GRIN2D': 28,
#  'GRIN1': 36,
#  'GRIN2C': 26,
#  'GRIN3A': 23,
#  'ATP7A': 4,
#  'GNB3': 3,
#  'IDH2': 3,
#  'SLC8A3': 1,
#  'MPDZ': 5,
#  'CUX2': 4,
#  'SLC17A7': 3,
#  'MIB1': 3,
#  'PHACTR1': 2,
#  'SCN8A': 2,
#  'AVPR2': 239,
#  'FDFT1': 1,
#  'UGP2': 1,
#  'PUM1': 2,
#  'ZNF292': 1,
#  'TRAPPC4': 1,
#  'AVPR1A': 38,
#  'AVPR1B': 1,
#  'ABCB4': 7,
#  'ITGB6': 7,
#  'KRT19': 2,
#  'TIMP1': 3,
#  'RARG': 115,
#  ...}

# %%
all_path['gene occurences(out of 335752 paths)'] = all_path.genes.apply(lambda x: {i: gene_count_per_path[i] for i in x})

# %%
gene_count_per_path_per_disease = {}
path_count_per_disease = {}
for disease, gene in tqdm(all_path[['Disease','genes']].values):
    if disease not in gene_count_per_path_per_disease:
        gene_count_per_path_per_disease[disease] = {}
        path_count_per_disease[disease] = 0
    for i in gene:
        if i in gene_count_per_path_per_disease[disease]:
            gene_count_per_path_per_disease[disease][i] += 1
        else:
            gene_count_per_path_per_disease[disease][i] = 1
    path_count_per_disease[disease] += 1
# Out:
#   0%|                                                                                                             | 0/335752 [00:00<?, ?it/s]
#  14%|█████████████▏                                                                               | 47413/335752 [00:00<00:00, 474111.24it/s]
#  31%|████████████████████████████▎                                                               | 103506/335752 [00:00<00:00, 525173.93it/s]
#  49%|████████████████████████████████████████████▋                                               | 163252/335752 [00:00<00:00, 558174.32it/s]
#  66%|████████████████████████████████████████████████████████████▊                               | 221849/335752 [00:00<00:00, 569140.28it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 335752/335752 [00:00<00:00, 578787.19it/s]

# %%
path_count_per_disease
# Out:
# {'von Hippel-Lindau disease': 2671,
#  'familial hypercholesterolemia': 18448,
#  'acquired polycythemia vera': 19932,
#  'psoriasis': 23359,
#  'CDKL5 disorder': 513,
#  'macular degeneration': 1261,
#  'atopic dermatitis': 574,
#  'asthma': 20978,
#  'cytomegalovirus infection': 6,
#  'type 2 diabetes mellitus': 7374,
#  'myelofibrosis': 2528,
#  'severe pre-eclampsia': 36,
#  'mycetoma': 2069,
#  'disorder of phenylalanine metabolism': 398,
#  'multiple congenital anomalies/dysmorphic syndrome-intellectual disability': 2,
#  'congenital myasthenic syndrome': 5797,
#  'NGLY1-deficiency': 5926,
#  'cryptosporidiosis': 18387,
#  'hypersensitivity pneumonitis': 6978,
#  'malignant hyperthermia of anesthesia': 4731,
#  'X-linked intellectual disability': 12958,
#  'limb-girdle muscular dystrophy': 5825,
#  'chromosome 1p36 deletion syndrome': 5272,
#  'epithelioid sarcoma': 4987,
#  'neuroendocrine neoplasm': 11,
#  'hepatic veno-occlusive disease': 502,
#  'infectious disease': 4453,
#  'Cowden disease': 8596,
#  'Ehlers-Danlos syndrome, classic type': 41130,
#  'seminoma': 9622,
#  'arthrogryposis, distal,': 2754,
#  'autosomal recessive cutis laxa type 2, classic type': 2162,
#  'diaphanospondylodysostosis': 632,
#  'hereditary continuous muscle fiber activity': 3064,
#  'arthrogryposis, distal, with intellectual disability and characteristic facies': 538,
#  'amyotrophic lateral sclerosis with polyglucosan bodies': 183,
#  'cholecystitis': 444,
#  'focal dermal hypoplasia': 6541,
#  'immune dysregulation-polyendocrinopathy-enteropathy-X-linked syndrome': 9528,
#  'deafness dystonia syndrome': 7565,
#  'mevalonic aciduria': 349,
#  'pancreatic insulinoma': 503,
#  'hereditary angioedema with C1Inh deficiency': 1827,
#  'otorhinolaryngologic disease': 50,
#  'Kleefstra syndrome': 8883,
#  'inherited neurodegenerative disorder': 1161,
#  'de Barsy syndrome': 606,
#  'reactive arthritis': 37192,
#  'supratentorial cancer': 1257,
#  'nephrogenic syndrome of inappropriate antidiuresis': 5273,
#  'trichothiodystrophy': 1219,
#  'Noonan syndrome-like disorder with loose anagen hair': 5711,
#  'neuronopathy, distal hereditary motor': 2986}

# %%
gene_count_per_path_per_disease
# Out:
# {'von Hippel-Lindau disease': {'EPAS1': 57,
#   'CCND1': 436,
#   'VHL': 348,
#   'STAT5A': 2,
#   'UBC': 20,
#   'EGLN3': 1,
#   'NEDD8': 1,
#   'PIM1': 3,
#   'PSMC3': 1,
#   'GLUL': 46,
#   'BCHE': 41,
#   'GHR': 34,
#   'AR': 2,
#   'THRA': 72,
#   'UGT1A1': 80,
#   'ABCB1': 249,
#   'SLCO1B3': 59,
#   'SLCO1C1': 66,
#   'SLC7A5': 94,
#   'ALB': 350,
#   'SERPINA7': 24,
#   'SLCO4A1': 67,
#   'SLC10A1': 24,
#   'SLCO4C1': 43,
#   'THRB': 63,
#   'IFNA2': 2,
#   'ESR2': 1,
#   'PTGS2': 2,
#   'AVP': 3,
#   'KNG1': 3,
#   'TRH': 1,
#   'GSK3B': 2,
#   'ESR1': 1,
#   'TCF4': 2,
#   'STAT3': 3,
#   'ABCG2': 58,
#   'CRYAB': 2,
#   'HIF1A': 2},
#  'familial hypercholesterolemia': {'PCSK9': 772,
#   'ABCA1': 1317,
#   'APOA2': 393,
#   'APOB': 536,
#   'APOC3': 392,
#   'APOE': 1261,
#   'CETP': 651,
#   'HMGCR': 2647,
#   'LIPC': 539,
#   'LPL': 1184,
#   'PON1': 442,
#   'PON2': 1111,
#   'SREBF2': 1282,
#   'LDLRAP1': 1040,
#   'ABCG5': 270,
#   'ABCG8': 307,
#   'GHR': 1027,
#   'PPP1R17': 181,
#   'UBC': 109,
#   'SREBF1': 17,
#   'ARMC6': 5,
#   'GCG': 2,
#   'UGT2B7': 611,
#   'ITGAL': 564,
#   'ABCB11': 141,
#   'SLCO1B1': 176,
#   'ABCB1': 1185,
#   'SLCO1B3': 207,
#   'UGT1A3': 276,
#   'ABCG2': 1045,
#   'SLC10A1': 141,
#   'PRKACA': 4,
#   'ETS1': 1,
#   'FLOT1': 3,
#   'FOXA2': 9,
#   'EP300': 20,
#   'FOXA1': 9,
#   'DERL1': 1,
#   'LGALS3': 2,
#   'PPARGC1A': 1,
#   'LGALS9': 2,
#   'VCP': 2,
#   'TP53': 8,
#   'ERLIN2': 2,
#   'NR1H4': 1,
#   'NR4A1': 1,
#   'MVK': 1,
#   'ADRB3': 2,
#   'APC': 2,
#   'IRS1': 12,
#   'LEPR': 2,
#   'PPARA': 570,
#   'NEIL1': 2,
#   'PPARGC1B': 3,
#   'ALB': 426,
#   'MMP25': 499,
#   'CES1': 334,
#   'NR1I2': 243,
#   'AKR1B1': 553,
#   'AKR1C3': 317,
#   'AKR1C2': 289,
#   'AKR1C1': 363,
#   'UGT1A9': 100,
#   'CBR1': 572,
#   'NR1H2': 1,
#   'CREB3': 1,
#   'PDZK1IP1': 1,
#   'PITX3': 3,
#   'LRP2': 3,
#   'EGFR': 2,
#   'LUC7L2': 1,
#   'CLU': 1,
#   'RBCK1': 1,
#   'MAPK3': 1,
#   'CREB1': 1,
#   'HOXC8': 1,
#   'MMP2': 2,
#   'GRB2': 1,
#   'PKP2': 2,
#   'ARMC8': 2,
#   'ANKAR': 2,
#   'PTPN3': 1,
#   'YBX1': 2,
#   'CTNNB1': 2,
#   'CTNND1': 2,
#   'GH1': 3,
#   'APOA1': 10,
#   'ADRB2': 2,
#   'C9': 2,
#   'ANXA2': 1,
#   'NOS3': 4,
#   'APOA5': 4,
#   'HDAC2': 579,
#   'UGT1A1': 300,
#   'SLCO2B1': 509,
#   'ABCC2': 313,
#   'SLC15A1': 238,
#   'SORT1': 2,
#   'TCF4': 6,
#   'HNF4G': 3,
#   'HNF4A': 6,
#   'JUND': 2,
#   'EWSR1': 1,
#   'CCND1': 1,
#   'SFXN5': 1,
#   'RDH13': 1,
#   'SLC25A1': 1,
#   'ABCC3': 486,
#   'UGT2B15': 166,
#   'ANPEP': 480,
#   'NPC1L1': 171,
#   'CTCF': 1,
#   'CEBPB': 4,
#   'NR3C1': 2,
#   'FOSL2': 1},
#  'acquired polycythemia vera': {'HBA1': 121,
#   'HBB': 104,
#   'JAK2': 672,
#   'IFNA2': 341,
#   'JAK1': 486,
#   'MPL': 248,
#   'SH2B3': 112,
#   'TET2': 162,
#   'GH1': 59,
#   'VHL': 143,
#   'EGLN1': 130,
#   'SLC30A10': 53,
#   'HBA2': 9,
#   'EGLN3': 10,
#   'BAX': 2,
#   'ACE': 3,
#   'RUNX1': 2,
#   'CSF2': 28,
#   'CSF3': 29,
#   'ETV6': 1,
#   'MTHFR': 17,
#   'APC': 2,
#   'GAP43': 5,
#   'RELN': 5,
#   'GAL': 6,
#   'NRSN1': 5,
#   'IL6': 9,
#   'ITGB3': 2,
#   'ALB': 2,
#   'PEPD': 1,
#   'BCHE': 176,
#   'PTEN': 1,
#   'PLCG1': 1,
#   'CHEK2': 12,
#   'NFKBIA': 4,
#   'SOCS1': 21,
#   'STAT5A': 4,
#   'HES1': 1,
#   'ERBB2': 6,
#   'SPRY2': 2,
#   'CDKN2A': 3,
#   'TP53': 4,
#   'GSK3B': 2,
#   'KRAS': 1,
#   'IRF1': 1,
#   'CREBBP': 5,
#   'TAL1': 4,
#   'HAVCR2': 2,
#   'CD274': 6,
#   'SYK': 4,
#   'CSF3R': 1,
#   'ZBTB16': 1,
#   'SMARCA4': 1,
#   'GATA1': 3,
#   'RAP1GDS1': 1,
#   'ARMC7': 1,
#   'PKP2': 1,
#   'ANKAR': 1,
#   'ARMC8': 1,
#   'ARVCF': 1,
#   'CTNND1': 1,
#   'PTPN6': 4,
#   'UBC': 4,
#   'TSHR': 2,
#   'GRB2': 4,
#   'SHC1': 2,
#   'GATA2': 3,
#   'EZH2': 1,
#   'MMP2': 1,
#   'AVP': 4,
#   'LTF': 2,
#   'SLC5A6': 1,
#   'CRH': 2,
#   'NPY': 1,
#   'OXT': 11,
#   'KNG1': 3},
#  'psoriasis': {'IL6': 1354,
#   'IL12B': 777,
#   'IL23A': 721,
#   'IL6R': 23,
#   'IL6ST': 16,
#   'IL2': 129,
#   'CXCL8': 422,
#   'RUNX3': 962,
#   'HLA-C': 1377,
#   'MKI67': 948,
#   'NOS2': 1602,
#   'REN': 518,
#   'TYK2': 1522,
#   'VNN2': 860,
#   'TRAF3IP2': 1150,
#   'IL36RN': 265,
#   'VNN3': 279,
#   'CARD14': 792,
#   'LCE3D': 225,
#   'TAGAP': 781,
#   'ZNF816': 581,
#   'NFKB1': 30,
#   'TCF7': 23,
#   'HDAC1': 9,
#   'IRF1': 7,
#   'POLR2A': 2,
#   'TBP': 16,
#   'CREBBP': 45,
#   'RELB': 1,
#   'NCOR2': 11,
#   'NR3C1': 3116,
#   'ARMC6': 7,
#   'ARMC8': 18,
#   'PKP3': 18,
#   'PKP2': 18,
#   'RAP1GDS1': 15,
#   'ANKAR': 18,
#   'ARVCF': 18,
#   'FOS': 23,
#   'CTNND1': 18,
#   'ETS1': 2,
#   'AR': 13,
#   'IRF5': 57,
#   'SOD2': 728,
#   'IL23R': 71,
#   'HCAR2': 11,
#   'HLA-B': 21,
#   'HLA-DQA1': 19,
#   'CD14': 14,
#   'PLA2G4A': 22,
#   'SHBG': 469,
#   'ANXA1': 1810,
#   'ZFP36': 9,
#   'ABCG2': 977,
#   'SLCO1A2': 938,
#   'SLC22A8': 335,
#   'SERPINA6': 456,
#   'HSD11B2': 648,
#   'NOTCH1': 8,
#   'ADRB2': 15,
#   'RPL10': 4,
#   'TNFSF9': 18,
#   'SPI1': 14,
#   'DDIT3': 4,
#   'TGFB1': 14,
#   'UBC': 153,
#   'PIM1': 5,
#   'HSPA5': 4,
#   'CALR': 5,
#   'SLC9A3R1': 4,
#   'JUND': 4,
#   'PTPN6': 3,
#   'GRAMD1A': 5,
#   'FOXA1': 4,
#   'FOXA2': 3,
#   'CENPB': 5,
#   'ABCB1': 1888,
#   'FPGS': 7,
#   'ABCC4': 4,
#   'HSD11B1': 944,
#   'PTGS2': 20,
#   'NR0B1': 197,
#   'CRP': 330,
#   'PPARG': 488,
#   'TNF': 883,
#   'CARM1': 417,
#   'ABCB11': 119,
#   'ALB': 867,
#   'NR1I2': 323,
#   'CCND1': 1,
#   'RPL23': 6,
#   'C1QA': 9,
#   'RPL15': 7,
#   'JAZF1': 2,
#   'CLU': 4,
#   'MUC1': 1,
#   'BIRC3': 1,
#   'TNFRSF13B': 1,
#   'NR1H4': 5,
#   'AURKB': 2,
#   'CALM2': 3,
#   'NCOR1': 2,
#   'NRIP1': 4,
#   'PPARGC1A': 3,
#   'NR0B2': 3,
#   'ESR1': 1,
#   'CD36': 1,
#   'RNF31': 1,
#   'RBCK1': 2,
#   'TNIP2': 1,
#   'NFATC4': 1,
#   'TRIM37': 3,
#   'NFE2L2': 1,
#   'AGT': 9,
#   'RNF13': 2,
#   'IFNB1': 2,
#   'BCHE': 4,
#   'SRD5A2': 155,
#   'AKR1D1': 58,
#   'HMOX1': 6,
#   'SIRT1': 1,
#   'CYSRT1': 2,
#   'APOE': 195,
#   'PTTG1': 138,
#   'TNIP1': 199,
#   'EGF': 2,
#   'LRP2': 1,
#   'C9': 1,
#   'FCGR2A': 4,
#   'GATA1': 4,
#   'IL12A': 1,
#   'GP1BB': 4},
#  'CDKL5 disorder': {'GABRA1': 23,
#   'GABRA4': 3,
#   'GABRB3': 4,
#   'GABRA6': 2,
#   'GABRA2': 4,
#   'GABRA3': 4,
#   'GABRG2': 5,
#   'CACNA1A': 1,
#   'HCN1': 2,
#   'CRH': 5,
#   'TBCD': 2,
#   'ADRA1B': 2,
#   'DRD2': 10,
#   'HTR1A': 5,
#   'HTR1B': 4,
#   'CAMK2G': 1,
#   'ADRA2A': 2,
#   'GNAO1': 2,
#   'WDR45': 2,
#   'PNKP': 1,
#   'HTR2A': 2,
#   'ABCB1': 1,
#   'HTR1D': 1,
#   'ALB': 1,
#   'ABCG2': 1},
#  'macular degeneration': {'VEGFA': 482,
#   'ANGPT2': 330,
#   'APOE': 145,
#   'C2': 56,
#   'CFH': 103,
#   'CFI': 88,
#   'HTRA1': 114,
#   'RLBP1': 33,
#   'RPGR': 114,
#   'SQSTM1': 133,
#   'FBLN5': 99,
#   'CFHR4': 6,
#   'NMNAT1': 93,
#   'RAX2': 35,
#   'FGD6': 84,
#   'UBC': 7,
#   'CTNNB1': 3,
#   'ANKAR': 1,
#   'ARMC6': 1,
#   'CTNND1': 1,
#   'ARVCF': 1,
#   'RAP1GDS1': 1,
#   'PKP2': 1,
#   'PDGFRB': 1,
#   'MGP': 1,
#   'MC2R': 55,
#   'MC5R': 29,
#   'MC1R': 326,
#   'MC4R': 88,
#   'MC3R': 21,
#   'CTCF': 2,
#   'TCF4': 1,
#   'GRIA1': 1,
#   'MTOR': 1,
#   'PTTG1': 2},
#  'atopic dermatitis': {'HRH1': 40,
#   'FLG': 65,
#   'CCR3': 1,
#   'CCR5': 1,
#   'IL6': 4,
#   'IL13': 7,
#   'PPARA': 1,
#   'S100A8': 1,
#   'CCL5': 1,
#   'CCL22': 1,
#   'EMSY': 1,
#   'IL33': 1,
#   'ALB': 15,
#   'ABCB1': 19,
#   'KCNH2': 5,
#   'IL4': 1},
#  'asthma': {'PARP1': 848,
#   'ADRB2': 3411,
#   'ALOX5': 288,
#   'CAT': 32,
#   'DNMT1': 923,
#   'HLA-DQA1': 628,
#   'HLA-DQB1': 687,
#   'HSD11B2': 505,
#   'IL1B': 769,
#   'IL4': 214,
#   'IL6R': 20,
#   'MMP9': 629,
#   'MUC7': 135,
#   'NOS2': 478,
#   'NPY': 272,
#   'PDE4D': 761,
#   'PLAU': 678,
#   'PTEN': 535,
#   'TIMP3': 689,
#   'GSDMB': 556,
#   'TSLP': 297,
#   'ORMDL3': 662,
#   'TGFB1': 819,
#   'TNF': 631,
#   'IL1RN': 457,
#   'PTGS2': 10,
#   'ALB': 1619,
#   'ADRB1': 1452,
#   'ADRB3': 319,
#   'SLC22A5': 945,
#   'SLC22A1': 979,
#   'SLC22A3': 1196,
#   'SLC22A4': 638,
#   'UGT1A4': 143,
#   'UGT1A9': 197,
#   'UGT2B15': 286,
#   'UGT1A8': 115,
#   'NGF': 412,
#   'PTGS1': 1023,
#   'ETS1': 22,
#   'ESR1': 10,
#   'JUN': 7,
#   'ARRDC3': 1,
#   'SRC': 7,
#   'SLC9A3R1': 8,
#   'SLC9A3R2': 5,
#   'GRB2': 8,
#   'UBC': 67,
#   'ARRB1': 6,
#   'SH3GL2': 2,
#   'CD4': 6,
#   'CDK15': 2,
#   'GTF2B': 4,
#   'FOSL2': 1,
#   'YBX1': 4,
#   'ABL1': 2,
#   'LRP2': 2,
#   'MAGI2': 2,
#   'PRNP': 2,
#   'IL7R': 3,
#   'SPTLC1': 2,
#   'EEF1A1': 2,
#   'TGFB2': 2,
#   'TGFBR2': 2,
#   'TGFBR1': 2,
#   'SMAD3': 2,
#   'MMP2': 6,
#   'SERPINA1': 2,
#   'COMT': 10,
#   'INS': 6,
#   'KCNJ8': 1,
#   'HCRT': 4,
#   'COL4A1': 1,
#   'PLAT': 3,
#   'AGT': 2,
#   'AGER': 2,
#   'PLCB1': 2,
#   'BCHE': 6,
#   'ACE': 2,
#   'GCG': 5,
#   'ACHE': 2,
#   'CRH': 2,
#   'DDT': 640,
#   'NR3C1': 906,
#   'ADRA2A': 6,
#   'ABCB1': 1666,
#   'ABCB11': 2,
#   'CHRM4': 2,
#   'GSTP1': 273,
#   'ORM1': 374,
#   'SLC22A2': 188,
#   'ORM2': 291,
#   'SUMO2': 2,
#   'IMMT': 1,
#   'PTGDS': 1,
#   'PRDX6': 1,
#   'LGALS3': 3,
#   'SERPINE1': 8,
#   'IL13': 48,
#   'MMP1': 112,
#   'PGR': 523,
#   'PLA2G4A': 2,
#   'PRKCA': 4,
#   'SERPINA6': 279,
#   'SLCO1B1': 226,
#   'NR3C2': 758,
#   'BMI1': 1,
#   'RELA': 14,
#   'NFKB1': 5,
#   'AR': 10,
#   'CDKN1A': 2,
#   'IL10': 4,
#   'BRCA1': 2,
#   'CTNND1': 15,
#   'ARMC8': 12,
#   'ANKAR': 15,
#   'RAP1GDS1': 15,
#   'ARVCF': 15,
#   'KAT2B': 4,
#   'ARMC7': 6,
#   'IRF8': 1,
#   'FOS': 3,
#   'LAMA5': 1,
#   'PRDM14': 2,
#   'PBX1': 1,
#   'ERBB2': 1,
#   'STAT5A': 1,
#   'FOXA1': 1,
#   'THRA': 1,
#   'ACVRL1': 1,
#   'HSP90AA1': 6,
#   'RNF2': 4,
#   'NLRP3': 3,
#   'FTH1': 1,
#   'ACP1': 1,
#   'ADRA1B': 3,
#   'NR0B1': 2},
#  'cytomegalovirus infection': {'ALB': 1,
#   'ABCG2': 1,
#   'SLC22A8': 1,
#   'ABCB1': 1,
#   'SLCO1B3': 1},
#  'type 2 diabetes mellitus': {'CAPN10': 167,
#   'CAT': 28,
#   'HP': 222,
#   'PAX4': 44,
#   'ABCC8': 585,
#   'HNF1A': 9,
#   'TNF': 77,
#   'IFNG': 3,
#   'IL6': 27,
#   'CASP3': 35,
#   'CASP8': 36,
#   'DPP4': 400,
#   'INSR': 381,
#   'LEPR': 214,
#   'PPARG': 1034,
#   'IRS2': 199,
#   'RETN': 52,
#   'ATP2A2': 235,
#   'CPT1A': 38,
#   'ICAM1': 219,
#   'SMAD5': 180,
#   'NEUROD1': 102,
#   'NOS2': 117,
#   'ENPP1': 162,
#   'RNF6': 166,
#   'SLC22A3': 263,
#   'MIRLET7D': 143,
#   'MIR1307': 41,
#   'MIR3173': 11,
#   'TNFRSF10A': 1,
#   'MIR222': 43,
#   'MIR375': 11,
#   'MIR1260B': 17,
#   'BCL10': 1,
#   'CCL11': 1,
#   'PTGS2': 8,
#   'GPT': 8,
#   'SERPINA1': 4,
#   'KNG1': 8,
#   'DDT': 3,
#   'ABCB1': 5,
#   'DDIT3': 2,
#   'HLA-DQB1': 2,
#   'IGF1': 8,
#   'TYK2': 5,
#   'AIFM1': 2,
#   'FOXP3': 18,
#   'SLC29A3': 2,
#   'CAV1': 4,
#   'HK1': 142,
#   'LEP': 80,
#   'ALB': 502,
#   'SLCO1B1': 103,
#   'MAOB': 680,
#   'SLCO1B3': 131,
#   'AR': 6,
#   'PRKAA2': 2,
#   'MC4R': 1,
#   'EDN1': 173,
#   'HMOX1': 118,
#   'SHBG': 59,
#   'UBC': 39,
#   'SNX27': 1,
#   'APOE': 6,
#   'MZT2B': 1,
#   'STAT5A': 1,
#   'ANKAR': 2,
#   'PIN1': 1,
#   'HTT': 2,
#   'NFYB': 1,
#   'LRP2': 1,
#   'STAT6': 1,
#   'NFE2L2': 1,
#   'B2M': 3,
#   'AMBP': 1,
#   'GSR': 1,
#   'AGT': 6,
#   'MAOA': 1,
#   'KCNJ11': 578,
#   'HMGA1': 74,
#   'PPARGC1A': 79,
#   'ABCB11': 163,
#   'KCNJ1': 202,
#   'ADRB2': 3,
#   'NR4A1': 1,
#   'CFTR': 2,
#   'F2RL1': 2,
#   'SRC': 1,
#   'H3C13': 1,
#   'NCOR2': 2,
#   'PRKCA': 3,
#   'GLI3': 1,
#   'GLI1': 1,
#   'NR0B2': 2,
#   'CAMK2A': 1,
#   'NCOR1': 1,
#   'NR1H4': 2,
#   'KCNJ8': 7,
#   'ESR2': 2,
#   'PTGS1': 3,
#   'C9': 2},
#  'myelofibrosis': {'CALR': 757,
#   'IFNG': 42,
#   'JAK2': 1023,
#   'MPL': 236,
#   'TET2': 593,
#   'PRF1': 1,
#   'ARMC8': 5,
#   'ANKAR': 5,
#   'PKP3': 1,
#   'PKP2': 2,
#   'RAP1GDS1': 1,
#   'ARMC7': 1,
#   'ARMC6': 1,
#   'CTNND1': 4,
#   'ARVCF': 1,
#   'ALB': 134,
#   'UBC': 31,
#   'SMARCA4': 4,
#   'STAT3': 2,
#   'JAK1': 200,
#   'ABCG2': 200,
#   'ABCB1': 231,
#   'FMO3': 62,
#   'SLC47A1': 94,
#   'FLT3': 75,
#   'SLC47A2': 40,
#   'POU2F2': 107,
#   'SLCO1B3': 21,
#   'SLCO1B1': 7,
#   'RNF2': 2,
#   'PTPN6': 7,
#   'SOCS1': 9,
#   'STAT5A': 4,
#   'GRB2': 7,
#   'ERBB2': 6,
#   'SHC1': 13,
#   'TAL1': 2,
#   'GATA2': 9,
#   'EZH2': 1,
#   'PRKCA': 81,
#   'PRKCD': 74,
#   'GATA1': 6,
#   'SNCA': 2,
#   'SEMG1': 1,
#   'YWHAG': 3,
#   'KIT': 137,
#   'PTGS1': 83,
#   'DDR1': 106,
#   'PDGFRB': 124,
#   'PDGFRA': 125,
#   'BCR': 128,
#   'ABL1': 152,
#   'SLC22A2': 25,
#   'SLC22A1': 57,
#   'ORM1': 23,
#   'HSP90B1': 1,
#   'STAT5B': 3,
#   'ETS1': 4,
#   'YWHAH': 1,
#   'IL6ST': 1,
#   'IL6': 1},
#  'severe pre-eclampsia': {'CACNA1A': 1,
#   'ITPA': 1,
#   'CHRM1': 2,
#   'CACNA1D': 1,
#   'DRD2': 2,
#   'HTR1A': 1},
#  'mycetoma': {'ABCB1': 50, 'UGT1A1': 2, 'FMO1': 2, 'FMO3': 2, 'PTGS1': 1},
#  'disorder of phenylalanine metabolism': {'PTGS2': 19,
#   'PAH': 335,
#   'QDPR': 2,
#   'GAMT': 1,
#   'TPH1': 7,
#   'TH': 12,
#   'PRKACA': 2,
#   'DGAT2': 14,
#   'HCAR2': 5,
#   'SLC5A8': 5,
#   'ABCG2': 17,
#   'XDH': 24,
#   'SLC22A7': 29,
#   'AOX1': 19,
#   'SLC22A2': 10,
#   'SLC22A8': 17,
#   'COX7B': 12,
#   'COX5B': 13,
#   'COX4I1': 14,
#   'ABCB1': 18,
#   'PLA2G1B': 5,
#   'COX6A2': 6,
#   'COX8A': 13,
#   'COX5A': 13,
#   'COX6C': 12,
#   'CES1': 7,
#   'MT-CO2': 4,
#   'ADH1C': 6,
#   'MT-CO1': 6,
#   'GPBAR1': 4,
#   'SLCO1B3': 2},
#  'multiple congenital anomalies/dysmorphic syndrome-intellectual disability': {},
#  'congenital myasthenic syndrome': {'ALDH2': 693,
#   'CHAT': 85,
#   'NPR1': 331,
#   'CHRNA1': 102,
#   'CHRNB1': 272,
#   'CHRND': 75,
#   'CHRNE': 172,
#   'DPAGT1': 526,
#   'GFPT1': 472,
#   'LRP4': 419,
#   'SCN4A': 223,
#   'SNAP25': 376,
#   'COLQ': 346,
#   'PREPL': 480,
#   'GMPPB': 310,
#   'ALG14': 382,
#   'AK9': 377,
#   'MYO9A': 489,
#   'SLC25A1': 490,
#   'PRKCE': 3,
#   'UBC': 42,
#   'RAD21': 1,
#   'GATA2': 1,
#   'SLC47A1': 424,
#   'SHBG': 246,
#   'SRD5A1': 480,
#   'MAOA': 587,
#   'SRD5A2': 144,
#   'SLC22A2': 98,
#   'AR': 519,
#   'ABCB1': 921,
#   'ALB': 272,
#   'SLCO1B3': 163,
#   'SLC22A7': 365,
#   'PRKCA': 8,
#   'SUZ12': 1,
#   'MAX': 3,
#   'MYC': 6,
#   'SUMO2': 2,
#   'TRIM68': 1,
#   'ESR2': 1,
#   'RHOA': 1,
#   'PEA15': 1,
#   'HDAC3': 1,
#   'CES1': 210,
#   'SLCO1B1': 51,
#   'PTGIR': 248},
#  'NGLY1-deficiency': {'ALDH2': 30,
#   'NPPA': 1,
#   'NPR1': 21,
#   'NPPB': 4,
#   'PGM1': 305,
#   'NGLY1': 287,
#   'UBC': 4,
#   'HSPB2': 1,
#   'ABCB1': 87,
#   'CES1': 29,
#   'PTGIR': 30,
#   'SLCO1B1': 12,
#   'SLCO1B3': 13,
#   'GABRA1': 65,
#   'GABRA3': 39,
#   'GABRA2': 54,
#   'GABRG2': 56,
#   'OPRM1': 1,
#   'OXT': 8,
#   'CRH': 2,
#   'HCN1': 1,
#   'P4HTM': 2,
#   'CNR1': 1,
#   'HTR1A': 1,
#   'TAC1': 1,
#   'VIP': 3,
#   'TRPV1': 1,
#   'GABRA5': 1,
#   'VCP': 1,
#   'UBQLN1': 3,
#   'ADRA1A': 63,
#   'ADRA2C': 93,
#   'DRD1': 33,
#   'ADRA2A': 94,
#   'ADRA2B': 55,
#   'ADRA1B': 48,
#   'ADRA1D': 44,
#   'TRH': 2,
#   'INS': 1,
#   'SLC5A6': 1,
#   'LEP': 1,
#   'NPY': 1,
#   'BCHE': 1,
#   'GCG': 1,
#   'IFNA2': 2,
#   'KNG1': 1,
#   'AP2M1': 1,
#   'EIF3F': 1,
#   'PAK1': 1},
#  'cryptosporidiosis': {'ALB': 85,
#   'ABCB1': 595,
#   'ABCC1': 30,
#   'ABCG2': 22,
#   'PPARG': 9,
#   'IFNA2': 18,
#   'IFNG': 16,
#   'ASPG': 3,
#   'SLC22A11': 24,
#   'SLC22A6': 40,
#   'SLC22A7': 33,
#   'FMO3': 21,
#   'SLC22A5': 19,
#   'SLC22A2': 56,
#   'SLC22A1': 58,
#   'HRH2': 28,
#   'SLC47A1': 18,
#   'SLC47A2': 12,
#   'TNF': 12,
#   'UGT1A1': 38,
#   'SLC19A1': 8,
#   'DHFR': 26,
#   'OPRM1': 1,
#   'POMC': 2,
#   'TNFRSF10A': 1,
#   'SLC22A8': 43,
#   'ACHE': 6},
#  'hypersensitivity pneumonitis': {'NOS2': 131,
#   'ALB': 576,
#   'ACAN': 777,
#   'NR3C1': 1436,
#   'HSD11B1': 669,
#   'ABCB1': 982,
#   'SLC22A8': 128,
#   'SLCO1A2': 346,
#   'NR1I2': 141,
#   'ABCG2': 266,
#   'ABCB11': 34,
#   'NR0B1': 76,
#   'CA1': 575,
#   'IL4': 527,
#   'MDM4': 1045,
#   'OVGP1': 826,
#   'IL27RA': 828,
#   'TMPRSS3': 633,
#   'HS3ST6': 130,
#   'TICAM1': 934,
#   'H3-4': 157,
#   'HLA-DRB1': 31,
#   'MMP8': 10,
#   'GATA1': 20,
#   'TAL1': 11,
#   'ETS1': 33,
#   'PTK2': 5,
#   'CSK': 3,
#   'CBX7': 1,
#   'RPL23': 9,
#   'DNMT1': 15,
#   'BIRC3': 1,
#   'TNFSF9': 10,
#   'KIAA0319L': 6,
#   'TLR5': 6,
#   'MAPK6': 4,
#   'UPF3A': 4,
#   'ARMC7': 1,
#   'RAP1GDS1': 7,
#   'PKP2': 7,
#   'ANKAR': 7,
#   'KPNA6': 7,
#   'ARMC8': 7,
#   'ARMC6': 2,
#   'PKP3': 7,
#   'CTNND1': 7,
#   'ARVCF': 7,
#   'AR': 6,
#   'RPS6KA5': 5,
#   'AURKB': 2,
#   'UBC': 54,
#   'CDKN1A': 5,
#   'JPH2': 5,
#   'RNF2': 4,
#   'PRKCZ': 3,
#   'VRK1': 1,
#   'TMX4': 3,
#   'IL27': 5,
#   'B4GALT1': 5,
#   'CARM1': 1,
#   'HGF': 4,
#   'SERPINA6': 266,
#   'EP300': 12,
#   'PDPK1': 2,
#   'EZH2': 4,
#   'CREBBP': 7,
#   'CXCL8': 13,
#   'TRAF5': 2,
#   'PIK3CA': 6,
#   'EBF1': 2,
#   'HSD11B2': 175,
#   'SRD5A2': 87,
#   'AKR1D1': 25,
#   'SHBG': 145,
#   'AIRE': 2,
#   'KAT2B': 1,
#   'HDAC1': 2,
#   'KAT2A': 1,
#   'CTBP1': 1,
#   'EEF1A1': 1,
#   'PTGS2': 203,
#   'BCHE': 167,
#   'CTNNB1': 2,
#   'SUMO1': 2,
#   'PSMC5': 1},
#  'malignant hyperthermia of anesthesia': {'AQP1': 43,
#   'CA2': 52,
#   'CA1': 18,
#   'CA4': 43,
#   'CA3': 34,
#   'CA7': 15,
#   'SLC22A6': 32,
#   'CA12': 24,
#   'CA14': 33,
#   'CCK': 2,
#   'CRH': 1,
#   'PTGS2': 3,
#   'PDYN': 5,
#   'NPPA': 2,
#   'CACNA1S': 313,
#   'RYR1': 455,
#   'CYSRT1': 1,
#   'REL': 1,
#   'PPP2CA': 2,
#   'SERPINA7': 9,
#   'IL1RN': 1,
#   'TNF': 4,
#   'CALM3': 3,
#   'RYR2': 1,
#   'POMC': 2,
#   'CBS': 17,
#   'GSS': 30,
#   'MGMT': 28,
#   'GOT2': 35,
#   'GCLM': 30,
#   'GOT1': 25,
#   'GCLC': 29,
#   'SLC16A10': 24,
#   'NFS1': 32,
#   'CTH': 34,
#   'CSAD': 28,
#   'GRB2': 1,
#   'LDHA': 18,
#   'SIRT5': 26,
#   'BST1': 16},
#  'X-linked intellectual disability': {'ACSL4': 2,
#   'VIP': 3,
#   'GABRA1': 455,
#   'GABRG2': 392,
#   'GABRA3': 258,
#   'GABRA2': 229,
#   'NSD2': 3,
#   'OXT': 4,
#   'P4HTM': 1,
#   'CRH': 4,
#   'BSCL2': 1,
#   'CLCN4': 578,
#   'RPS6KA3': 644,
#   'ZNF41': 353,
#   'IQSEC2': 545,
#   'UPF3B': 536,
#   'ZNF81': 488,
#   'PLAG1': 394,
#   'SMS': 272,
#   'HMGA2': 131,
#   'NONO': 396,
#   'PHF8': 509,
#   'NR4A2': 1,
#   'ADRA1B': 148,
#   'DRD1': 114,
#   'ADRA2B': 180,
#   'ADRA1A': 233,
#   'ADRA2A': 388,
#   'ADRA2C': 374,
#   'ADRA1D': 154,
#   'EIF3F': 1,
#   'SLC5A6': 1,
#   'LHB': 1,
#   'AHR': 1,
#   'NPPB': 3,
#   'FLNA': 181,
#   'AR': 10,
#   'GATA2': 6,
#   'YBX1': 3,
#   'NEK3': 1,
#   'PPP1R9B': 4,
#   'AP2M1': 1,
#   'ALDH2': 430,
#   'UBC': 15,
#   'SPI1': 2,
#   'NPPA': 1,
#   'NPR1': 233,
#   'PRDM14': 2,
#   'GABRA5': 179,
#   'GABRB3': 385,
#   'GABRD': 227,
#   'GABRB1': 249,
#   'GABRG3': 111,
#   'GABRA6': 50,
#   'FMR1': 1,
#   'GABRA4': 207,
#   'GABRB2': 280,
#   'GABRQ': 112,
#   'GABRG1': 177,
#   'POMC': 2,
#   'NOS2': 2,
#   'TNF': 4,
#   'APP': 1,
#   'CASP8': 1,
#   'NFKB1': 1,
#   'TGM1': 2},
#  'limb-girdle muscular dystrophy': {'ACHE': 241,
#   'BCHE': 314,
#   'COL6A1': 326,
#   'FKTN': 406,
#   'LAMA2': 292,
#   'SELENON': 122,
#   'PRIMA1': 222,
#   'POMK': 57,
#   'DAG1': 274,
#   'CCL2': 13,
#   'RXYLT1': 32,
#   'B4GAT1': 218,
#   'GMPPB': 136,
#   'TTN': 159,
#   'TCAP': 165,
#   'SGCA': 106,
#   'BVES': 139,
#   'DMD': 985,
#   'NKX2-5': 1,
#   'LUM': 167,
#   'CAPN3': 112,
#   'SGCG': 85,
#   'DYSF': 213,
#   'TRIM32': 189,
#   'POGLUT1': 178,
#   'UTRN': 1,
#   'UBC': 6,
#   'NR3C1': 504,
#   'SGTA': 1,
#   'ANKRD1': 2,
#   'NEDD8': 1,
#   'CALM2': 1,
#   'PON2': 1,
#   'SLCO1B3': 113,
#   'SLC22A8': 214,
#   'UGT1A9': 150,
#   'SLC22A6': 281,
#   'HSPA5': 1,
#   'CHPT1': 1,
#   'SLC22A5': 687,
#   'SLC6A2': 277,
#   'SLC6A3': 143,
#   'SLC22A2': 148,
#   'SLC22A4': 409,
#   'POLG': 4,
#   'P4HTM': 1,
#   'RACK1': 1,
#   'CAMK2A': 1},
#  'chromosome 1p36 deletion syndrome': {'GABRA1': 162,
#   'GABRA3': 116,
#   'GABRA2': 151,
#   'GABRG2': 164,
#   'CRH': 6,
#   'OPRM1': 2,
#   'OXT': 6,
#   'HCN1': 2,
#   'GABRA5': 2,
#   'GABRB2': 2,
#   'GABRB3': 2,
#   'P4HTM': 3,
#   'RERE': 328,
#   'GABRD': 471,
#   'SKI': 333,
#   'KCNAB2': 314,
#   'PRDM16': 271,
#   'DNAJC18': 2,
#   'UBQLN1': 3,
#   'ALDH2': 150,
#   'UBC': 3,
#   'SPI1': 2,
#   'ADRA1A': 104,
#   'ADRA2C': 165,
#   'DRD1': 71,
#   'ADRA2A': 167,
#   'ADRA1B': 66,
#   'FLNA': 1,
#   'GNAO1': 1,
#   'BCHE': 2,
#   'INS': 2,
#   'LEP': 2,
#   'NPY': 2,
#   'TRH': 2,
#   'ABCB1': 141,
#   'SLC5A6': 2,
#   'ADRA2B': 75,
#   'AP2M1': 1,
#   'EIF3F': 1,
#   'ADRA1D': 69,
#   'VIM': 1,
#   'MDFI': 1,
#   'ANKAR': 1,
#   'ARMC8': 1,
#   'CTNND1': 1,
#   'GATA2': 5,
#   'AR': 2,
#   'AKT2': 1,
#   'NPR1': 70,
#   'CES1': 55,
#   'SLCO1B1': 11,
#   'SLCO1B3': 25,
#   'PTGIR': 61,
#   'ATG9A': 1},
#  'epithelioid sarcoma': {'CSF2': 166,
#   'SOX2': 389,
#   'TP53': 763,
#   'MCL1': 617,
#   'SMARCA4': 655,
#   'PRAME': 297,
#   'ZNF536': 6,
#   'PTGS2': 6,
#   'ELOC': 6,
#   'CD22': 173,
#   'EEF2': 303,
#   'NF1': 583,
#   'PAX3': 184,
#   'MAML3': 458,
#   'ZNF667-AS1': 519,
#   'HNRNPD': 2,
#   'GRB2': 3,
#   'PARK7': 2,
#   'EEF1A1': 1,
#   'PTPN6': 2,
#   'SUMO2': 1,
#   'TLR5': 1,
#   'CCT3': 1,
#   'NEDD8': 4,
#   'MAX': 2,
#   'PRKCA': 342,
#   'PRKCD': 267,
#   'PIK3CA': 375,
#   'RAP1GDS1': 6,
#   'ETS1': 23,
#   'SPI1': 6,
#   'ANKAR': 6,
#   'ARMC8': 4,
#   'CTNND1': 6,
#   'PKP2': 6,
#   'UBC': 72,
#   'AR': 20,
#   'FOXP3': 11,
#   'RPS6KA5': 1,
#   'KRT18': 1,
#   'CDKN1A': 10,
#   'RPS6KA2': 2,
#   'MAPK10': 2,
#   'EWSR1': 2,
#   'ABCB1': 629,
#   'FLT4': 244,
#   'FLT1': 373,
#   'KDR': 356,
#   'SLCO1B1': 38,
#   'UGT1A1': 67,
#   'ARMC6': 4,
#   'ARVCF': 4,
#   'RNF2': 8,
#   'ARMC7': 2,
#   'TCF4': 1,
#   'PTK2': 1,
#   'LGALS3': 3,
#   'ERBB2': 4,
#   'MET': 4,
#   'HDAC4': 391,
#   'HDAC6': 360,
#   'HDAC2': 407,
#   'ABCC1': 327,
#   'HDAC1': 444,
#   'SLCO1B3': 64,
#   'FOS': 4,
#   'GATA1': 6,
#   'RUNX1': 6,
#   'IKZF1': 2,
#   'BMF': 1,
#   'MAPK1': 12,
#   'MAPK9': 2,
#   'VCP': 2,
#   'FYN': 6,
#   'SIN3A': 12,
#   'H2AC20': 1,
#   'KDM1A': 4,
#   'FLOT1': 1,
#   'GP1BB': 2,
#   'ATM': 16,
#   'CEBPA': 2,
#   'CREBBP': 6,
#   'RBPJ': 2,
#   'RBL1': 2,
#   'PKM': 1,
#   'SAP130': 2,
#   'CHD3': 6,
#   'UBD': 1,
#   'EFEMP2': 1,
#   'DDX17': 2,
#   'E2F4': 2,
#   'E4F1': 1,
#   'ALB': 1,
#   'BAX': 2,
#   'CD28': 7,
#   'ZEB1': 1,
#   'TET2': 7,
#   'EZH2': 2},
#  'neuroendocrine neoplasm': {'PARP1': 2,
#   'CD86': 1,
#   'POU2F2': 1,
#   'PARP2': 1,
#   'IKZF3': 3,
#   'ALOX5': 2,
#   'GRB2': 1},
#  'hepatic veno-occlusive disease': {'IL1B': 83,
#   'CSF3': 90,
#   'OCLN': 64,
#   'F5': 68,
#   'JAK2': 86,
#   'GATA2': 2,
#   'EGR1': 3,
#   'STAT3': 12,
#   'ARMC8': 2,
#   'ANKAR': 2,
#   'PKP2': 2,
#   'RAP1GDS1': 2,
#   'ARMC7': 2,
#   'CTNND1': 2,
#   'OLR1': 2,
#   'PLCG2': 1,
#   'TNFRSF1A': 1,
#   'C5': 48,
#   'PITX3': 2,
#   'IFNG': 66,
#   'PKP3': 1,
#   'ARMC6': 1,
#   'ARVCF': 1,
#   'ALB': 123,
#   'NR5A2': 1,
#   'SOD1': 1,
#   'UBC': 2,
#   'F13B': 23},
#  'infectious disease': {'TPSAB1': 2,
#   'IL1RN': 26,
#   'SLC22A6': 48,
#   'CD209': 520,
#   'ABCB5': 7,
#   'CLU': 3,
#   'ABCB11': 23,
#   'ABCC2': 37,
#   'SLCO1B1': 9,
#   'ABCG2': 21,
#   'UGT1A1': 5,
#   'TOP2A': 51,
#   'ABCB1': 34,
#   'SLC47A2': 14,
#   'SLC47A1': 22,
#   'KCNH2': 18,
#   'CD36': 1,
#   'CSF3': 8,
#   'CXCL8': 2,
#   'TLR2': 1,
#   'HTR1B': 2,
#   'SLC22A5': 56,
#   'ABCC1': 27,
#   'SLC22A4': 25,
#   'C9': 1,
#   'ALB': 23,
#   'SLC22A11': 18,
#   'SLC22A8': 40,
#   'SLC15A1': 76,
#   'SLC15A2': 80,
#   'SLCO2B1': 23,
#   'SLCO3A1': 21,
#   'SLCO4A1': 20},
#  'Cowden disease': {'ALDH2': 364,
#   'AKT1': 1021,
#   'NPR1': 173,
#   'FGFR2': 909,
#   'PIK3CA': 914,
#   'PTEN': 892,
#   'SDHB': 722,
#   'SDHC': 625,
#   'SDHD': 634,
#   'SEC23B': 694,
#   'KLLN': 307,
#   'GATA2': 10,
#   'UBC': 60,
#   'EP300': 1,
#   'ADRA1A': 240,
#   'ADRA1B': 123,
#   'DRD1': 129,
#   'ADRA2B': 165,
#   'ADRA2A': 363,
#   'ADRA2C': 330,
#   'AP2M1': 1,
#   'EIF3F': 1,
#   'BCHE': 1,
#   'CRH': 1,
#   'INS': 1,
#   'LEP': 1,
#   'NPY': 1,
#   'OXT': 2,
#   'TRH': 3,
#   'SLC5A6': 1,
#   'ADRA1D': 138,
#   'VIM': 1,
#   'FLNA': 1,
#   'CSK': 1,
#   'AR': 6,
#   'NR3C1': 1,
#   'FLNC': 3,
#   'BUB1': 4,
#   'YBX1': 4,
#   'UCHL1': 3,
#   'STAT6': 1,
#   'MDFI': 1,
#   'ANKAR': 5,
#   'GRB2': 12,
#   'RPS6KA2': 3,
#   'STAT5A': 2,
#   'SRPK1': 2,
#   'STK11': 3,
#   'PIK3R1': 451,
#   'SOD1': 374,
#   'ADRB1': 198,
#   'ADRB2': 338,
#   'MAPK1': 412,
#   'ADRB3': 111,
#   'CACNA1D': 1,
#   'HTR1A': 1,
#   'IL6R': 1,
#   'IL6ST': 1,
#   'EIF4A3': 1,
#   'PIK3R3': 358,
#   'PIK3R2': 261,
#   'KCNH2': 3,
#   'LMNA': 3,
#   'ERBB2': 6,
#   'PKM': 2,
#   'MAPK9': 1,
#   'HTT': 3,
#   'ETS1': 15,
#   'PTK2': 9,
#   'ESR1': 16,
#   'VCP': 3,
#   'SRC': 15,
#   'GSK3B': 6,
#   'ARRB1': 4,
#   'ARMC8': 4,
#   'NFATC4': 1,
#   'CTNND1': 5,
#   'HAVCR2': 6,
#   'RNF19B': 2,
#   'CD40': 1,
#   'PDE4D': 2,
#   'CD28': 1,
#   'UBA1': 1,
#   'TAF1': 2,
#   'MAGI2': 1,
#   'TIMM50': 1,
#   'SLC25A5': 3,
#   'ARHGDIA': 1,
#   'XRCC6': 1,
#   'CPSF7': 1,
#   'SUMO2': 2,
#   'ABCB1': 361,
#   'UGT1A1': 91,
#   'SLCO1C1': 182,
#   'ALB': 231,
#   'SLCO1B3': 66,
#   'THRA': 341,
#   'SLC7A5': 379,
#   'SLCO4C1': 144,
#   'SERPINA7': 55,
#   'SLCO4A1': 279,
#   'MS4A1': 1,
#   'SLC10A1': 79,
#   'STAT3': 2,
#   'TNFRSF1A': 1,
#   'GTF2B': 1,
#   'MAPKAP1': 1,
#   'EGR1': 2,
#   'DLG1': 1,
#   'TMED2': 1,
#   'MTNR1B': 1,
#   'NRAS': 6,
#   'RET': 5,
#   'BRAF': 5,
#   'NCOA4': 1,
#   'RXRA': 1,
#   'KRAS': 6,
#   'ZEB1': 3},
#  'Ehlers-Danlos syndrome, classic type': {'RARB': 157,
#   'COL3A1': 1288,
#   'ALDH1A1': 277,
#   'RARA': 294,
#   'ALDH1A2': 215,
#   'RBP4': 264,
#   'ALB': 1179,
#   'RARRES1': 165,
#   'RSPH4A': 1,
#   'CSF3': 1,
#   'RXRG': 131,
#   'CRABP2': 221,
#   'COL1A1': 1303,
#   'OBP2A': 73,
#   'LCN1': 47,
#   'COL1A2': 1239,
#   'SLC39A13': 1204,
#   'B3GALT6': 1005,
#   'COL5A1': 1005,
#   'COL5A2': 1005,
#   'MMP9': 30,
#   'SMAD4': 1,
#   'EIF3F': 3,
#   'OPRM1': 10,
#   'TFAP2C': 20,
#   'COL8A2': 8,
#   'E2F1': 3,
#   'COL6A2': 1,
#   'ABCB1': 1124,
#   'PTGS1': 279,
#   'PTGS2': 465,
#   'UGT1A9': 91,
#   'UGT1A3': 80,
#   'SLCO1C1': 271,
#   'PLA2G2A': 184,
#   'ALOX5': 255,
#   'SLC22A11': 99,
#   'UGT2B4': 86,
#   'ASIC1': 154,
#   'TNF': 29,
#   'MVK': 7,
#   'DCN': 2,
#   'REL': 4,
#   'IGFBP3': 3,
#   'CD40': 3,
#   'TGM2': 6,
#   'PTPN2': 5,
#   'THRA': 230,
#   'SLCO1B3': 56,
#   'SLC7A5': 258,
#   'UGT1A1': 100,
#   'SLCO4C1': 112,
#   'SERPINA7': 63,
#   'SLCO4A1': 193,
#   'SLC10A1': 63,
#   'IFNG': 4,
#   'ASPG': 1,
#   'RXRA': 1,
#   'TCF4': 2,
#   'HSD11B1': 267,
#   'NOS2': 130,
#   'ABCG2': 294,
#   'SERPINF1': 2,
#   'SPARC': 4,
#   'ABCB11': 134,
#   'NR0B1': 74,
#   'SLCO1A2': 207,
#   'NR3C1': 622,
#   'SLC22A8': 144,
#   'NR1I2': 135,
#   'IFNA2': 18,
#   'LIG4': 4,
#   'MMP1': 8,
#   'SPI1': 6,
#   'TGFB1': 6,
#   'SGTA': 2,
#   'E2F6': 2,
#   'F2RL1': 1,
#   'BCHE': 164,
#   'SERPINA6': 110,
#   'IL6': 7,
#   'COCH': 1,
#   'ACHE': 1},
#  'seminoma': {'FGFR3': 778,
#   'HRAS': 1248,
#   'KIT': 1002,
#   'ERCC1': 831,
#   'STK11': 1029,
#   'BAP1': 1057,
#   'ATF7IP': 736,
#   'CD9': 14,
#   'ERCC4': 827,
#   'TLR2': 232,
#   'ABCB11': 93,
#   'ABCC1': 775,
#   'ABCB1': 876,
#   'ABCC2': 177,
#   'ABCC6': 383,
#   'TOP2A': 426,
#   'ABCG2': 463,
#   'ABCC3': 193,
#   'ENTPD6': 726,
#   'NDUFS3': 286,
#   'NOS1': 183,
#   'NQO1': 308,
#   'ABCB8': 202,
#   'XDH': 130,
#   'NDUFS2': 267,
#   'ALB': 144,
#   'CBR1': 264,
#   'AKR1C3': 126,
#   'DMRT1': 137,
#   'KITLG': 696,
#   'TLR3': 216,
#   'GSK3B': 12,
#   'GATA2': 12,
#   'UBC': 168,
#   'PBX3': 2,
#   'TP53': 44,
#   'PTPN6': 2,
#   'EGR1': 8,
#   'JUN': 313,
#   'SP2': 2,
#   'EGFR': 44,
#   'PLK1': 4,
#   'MAPRE1': 6,
#   'MYC': 48,
#   'BRCA1': 27,
#   'YY1': 3,
#   'VHL': 7,
#   'ERBB2': 40,
#   'PIK3CG': 24,
#   'IRAK2': 2,
#   'KRT18': 2,
#   'CTNNA1': 4,
#   'BRAF': 44,
#   'STAT5A': 8,
#   'PTPN11': 7,
#   'CBLB': 6,
#   'CLTC': 10,
#   'TRIM29': 2,
#   'SLX4': 12,
#   'SPI1': 11,
#   'FANCA': 8,
#   'SLC22A18': 4,
#   'KLHDC10': 2,
#   'WT1': 13,
#   'CREBBP': 30,
#   'MLF1': 6,
#   'HGF': 10,
#   'RPS6KB1': 12,
#   'HDLBP': 1,
#   'ASXL1': 3,
#   'NBN': 8,
#   'EPG5': 1,
#   'EHMT2': 6,
#   'ARMC7': 2,
#   'ANKAR': 2,
#   'ARMC8': 2,
#   'MAP3K7': 1,
#   'RAP1GDS1': 2,
#   'BMPR1A': 1,
#   'CTNND1': 2,
#   'PKP2': 1,
#   'TUBB': 251,
#   'SLCO1B1': 44,
#   'PTGS1': 5,
#   'GSTP1': 14,
#   'TOP2B': 4,
#   'POU5F1': 3,
#   'TUBA1A': 225,
#   'TUBD1': 204,
#   'TUBG1': 236,
#   'TUBE1': 190,
#   'NRF1': 1,
#   'RACGAP1': 1,
#   'GATA1': 2,
#   'ATG3': 1,
#   'GTF2B': 2,
#   'SOCS6': 2,
#   'CTCF': 1,
#   'SUMO2': 4,
#   'MARK4': 3,
#   'VBP1': 1,
#   'MAPK3': 2,
#   'MTHFD2': 6,
#   'YAP1': 1,
#   'MET': 1,
#   'PTGS2': 1,
#   'BUB1B': 1,
#   'SLC22A5': 181,
#   'SLC9A3R2': 1,
#   'ESR1': 6,
#   'ETV4': 1,
#   'FGFR4': 1,
#   'SOX4': 1,
#   'LIG1': 158,
#   'BLMH': 211,
#   'STAT3': 4,
#   'CTNNB1': 3,
#   'PIK3CA': 9,
#   'MTOR': 1,
#   'CDKN2A': 7,
#   'BUB1': 1,
#   'PAK1': 1,
#   'CDK4': 1},
#  'arthrogryposis, distal,': {'SLCO2B1': 170,
#   'SLCO2A1': 164,
#   'ABCC5': 188,
#   'ABCC4': 154,
#   'PTGER2': 106,
#   'PTGER1': 40,
#   'MYBPC1': 180,
#   'SLCO3A1': 179,
#   'PTGDR2': 63,
#   'MYH3': 217,
#   'TNNI2': 169,
#   'TNNT3': 180,
#   'TPM2': 357,
#   'NALCN': 226,
#   'PIEZO2': 316,
#   'CTNNA3': 1,
#   'HNF4G': 1,
#   'UBC': 5,
#   'OXTR': 67,
#   'GNRHR': 50,
#   'GNRHR2': 75,
#   'GHR': 102,
#   'PRLR': 65,
#   'LGALS3': 116,
#   'GLTP': 124,
#   'GLT6D1': 8},
#  'autosomal recessive cutis laxa type 2, classic type': {'ALDH2': 46,
#   'ATP6V1A': 207,
#   'NPR1': 34,
#   'ATP6V1E1': 194,
#   'ATP6V0A2': 183,
#   'UBC': 3,
#   'PTGFR': 61,
#   'ADRA1B': 50,
#   'ADRA1A': 66,
#   'ADRA1D': 45,
#   'ADRA2A': 96,
#   'SLC5A6': 2,
#   'BCHE': 1,
#   'CRH': 2,
#   'INS': 1,
#   'LEP': 1,
#   'NPY': 1,
#   'OPRK1': 2,
#   'OXT': 2,
#   'PTGS2': 3,
#   'TRH': 4,
#   'AP2M1': 1,
#   'EIF3F': 2,
#   'BDNF': 2,
#   'YBX1': 2,
#   'KIAA2013': 1,
#   'EFEMP2': 1,
#   'PTGER3': 73,
#   'PTGER1': 26,
#   'BMPR1A': 1,
#   'KCNK3': 52,
#   'FBLN5': 1,
#   'KCNK9': 33,
#   'S100A10': 1},
#  'diaphanospondylodysostosis': {'MECP2': 8,
#   'OPRM1': 41,
#   'PDYN': 10,
#   'BMPER': 151,
#   'ABCB1': 25,
#   'OPRK1': 9,
#   'ABCG2': 17,
#   'IGF1R': 2,
#   'MAPT': 2,
#   'TBCD': 3,
#   'SLC23A1': 2,
#   'FBLN5': 2,
#   'IFT80': 2,
#   'MGME1': 2,
#   'OPRD1': 10,
#   'OPRL1': 16,
#   'NR1I2': 4,
#   'CHRNB4': 10,
#   'CHRNA3': 16},
#  'hereditary continuous muscle fiber activity': {'ABCG2': 23,
#   'ALB': 31,
#   'APOE': 1,
#   'SNX27': 1,
#   'SOD1': 2,
#   'KCNA1': 222,
#   'NR1I2': 12,
#   'GRIN2A': 41,
#   'ABCC2': 22,
#   'UGT1A1': 31,
#   'CHRNA4': 27,
#   'GABRA1': 53,
#   'GRIN2B': 36,
#   'GRIN2D': 25,
#   'GRIN1': 34,
#   'ABCB1': 101,
#   'GRIN2C': 26,
#   'GRIN3A': 23,
#   'ATP7A': 3,
#   'BCHE': 4,
#   'BDNF': 3,
#   'CCK': 2,
#   'CLU': 3,
#   'CNR1': 4,
#   'CRH': 4,
#   'GABRA5': 3,
#   'GNB3': 3,
#   'HTR1A': 5,
#   'IDH2': 3,
#   'IL1B': 4,
#   'IL6': 5,
#   'NOS2': 4,
#   'OPRM1': 4,
#   'OXT': 6,
#   'POLG': 3,
#   'POMC': 6,
#   'PTGS2': 3,
#   'SLC8A3': 1,
#   'TBCD': 3,
#   'MPDZ': 3,
#   'PNKP': 3,
#   'CUX2': 2,
#   'SLC17A7': 3,
#   'MIB1': 3,
#   'PHACTR1': 1,
#   'HCN1': 3,
#   'SCN8A': 2,
#   'AP2M1': 1,
#   'SLCO2A1': 11,
#   'DLG1': 4},
#  'arthrogryposis, distal, with intellectual disability and characteristic facies': {'ACHE': 4,
#   'AVPR2': 6,
#   'PTGS1': 2,
#   'PTGS2': 3,
#   'FDFT1': 1,
#   'UGP2': 1,
#   'PUM1': 1,
#   'ZNF292': 1,
#   'TRAPPC4': 1,
#   'MECP2': 1,
#   'OPRM1': 1,
#   'PDYN': 2,
#   'TBCD': 1,
#   'AVPR1A': 3,
#   'AVPR1B': 1},
#  'amyotrophic lateral sclerosis with polyglucosan bodies': {'HRH1': 1,
#   'PTGS2': 1,
#   'CLU': 1,
#   'TNF': 2,
#   'MAOA': 1,
#   'INSR': 4,
#   'CTNNB1': 2,
#   'IGF1R': 1},
#  'cholecystitis': {'ABCB4': 7,
#   'ITGB6': 7,
#   'SLC22A8': 10,
#   'ABCB11': 3,
#   'SLC15A1': 11,
#   'SLC15A2': 6,
#   'EGR1': 8,
#   'ALB': 5,
#   'SLC22A11': 2,
#   'SLC22A6': 2,
#   'COL1A1': 2,
#   'KRT19': 2,
#   'TGFB2': 3,
#   'TIMP1': 3},
#  'focal dermal hypoplasia': {'RARB': 20,
#   'RARG': 18,
#   'RARA': 14,
#   'PORCN': 241,
#   'ALB': 57,
#   'ABCG2': 11,
#   'APOE': 1,
#   'PDGFRA': 19,
#   'PDGFRB': 25,
#   'RHOA': 1,
#   'BCR': 20,
#   'TP63': 3,
#   'DDR1': 12,
#   'ORM1': 19,
#   'GJB6': 1,
#   'ABCB1': 166,
#   'PTGS1': 27,
#   'KIT': 19,
#   'ABL1': 16,
#   'SLC22A2': 16,
#   'SLC22A1': 21,
#   'TLR4': 1,
#   'VIP': 1,
#   'NR3C1': 34,
#   'ABCB11': 50,
#   'SLCO1B1': 33,
#   'SLCO1B3': 15,
#   'PGR': 16,
#   'KLK3': 10,
#   'NR1I2': 10,
#   'OXT': 3},
#  'immune dysregulation-polyendocrinopathy-enteropathy-X-linked syndrome': {'FOXP3': 254,
#   'AIFM1': 6,
#   'CCR5': 2,
#   'INSR': 45,
#   'IGF1R': 34,
#   'OXT': 2,
#   'ACTR6': 1,
#   'IDE': 1,
#   'UBC': 7,
#   'CTNND1': 2,
#   'STAT5A': 1,
#   'ABCB1': 337,
#   'SLCO1B3': 34,
#   'SLCO1C1': 21,
#   'THRA': 28,
#   'SLC7A5': 36,
#   'SERPINA7': 24,
#   'SLCO2B1': 62,
#   'ALB': 131,
#   'SLCO4A1': 23,
#   'SLC16A2': 14,
#   'ESR1': 1,
#   'TCF4': 2,
#   'GSK3B': 1,
#   'PARP1': 1,
#   'PIM1': 2,
#   'BRAF': 5,
#   'IL1B': 1,
#   'TSHR': 3,
#   'IRS1': 2,
#   'RET': 4,
#   'PRKAR1A': 5,
#   'APC': 2,
#   'NTRK2': 1,
#   'IL4': 1,
#   'MGAM': 6,
#   'ATP2A2': 1},
#  'deafness dystonia syndrome': {'AR': 308,
#   'MAOA': 144,
#   'ALB': 251,
#   'SHBG': 132,
#   'ABCG2': 58,
#   'SLC22A8': 74,
#   'SLCO1B3': 42,
#   'NR3C2': 62,
#   'ATP7A': 1,
#   'HTR1A': 1,
#   'TIMM8A': 392,
#   'TBP': 841,
#   'STAM': 4,
#   'UBC': 30,
#   'SIN3A': 6,
#   'NR3C1': 59,
#   'EEF1A1': 9,
#   'AHR': 3,
#   'RPS6': 4,
#   'PRL': 21,
#   'ABCB1': 121,
#   'SRD5A2': 21,
#   'SLC22A2': 29,
#   'SLC22A7': 46,
#   'SLC47A1': 52,
#   'SRD5A1': 52,
#   'DHX9': 1,
#   'MYC': 2,
#   'GTF2B': 1,
#   'PRLR': 24,
#   'GHR': 31,
#   'MBD2': 1,
#   'HSD11B2': 27,
#   'MTRNR2L1': 1,
#   'MAP1LC3B': 1,
#   'ESR1': 64,
#   'CTBP1': 2,
#   'TNF': 2,
#   'INS': 2,
#   'MYO1C': 1,
#   'SLCO1A2': 40,
#   'KRT15': 1},
#  'mevalonic aciduria': {'IFNG': 13,
#   'HMGCR': 136,
#   'IL1B': 27,
#   'CLU': 2,
#   'RELB': 1,
#   'GHR': 53,
#   'PRLR': 14,
#   'UBC': 5,
#   'LGALS3': 12,
#   'GLTP': 13,
#   'GLT6D1': 2,
#   'BCHE': 22,
#   'GLUL': 31},
#  'pancreatic insulinoma': {'GLUL': 26,
#   'KCNMA1': 21,
#   'MEN1': 427,
#   'MAFA': 1,
#   'CA1': 13,
#   'CA2': 18,
#   'ATP1A1': 23,
#   'KCNJ11': 12,
#   'UBC': 6,
#   'NFKB1': 1,
#   'NPR1': 11,
#   'ALDH2': 13,
#   'CRABP1': 13,
#   'RARA': 29,
#   'RARB': 15,
#   'WT1': 1,
#   'H4C14': 1,
#   'NR1H3': 1,
#   'S100P': 13,
#   'MYH9': 1,
#   'ABCC5': 35,
#   'SLCO3A1': 31,
#   'ABCC4': 31,
#   'SLCO2A1': 31,
#   'SLCO2B1': 28,
#   'PTGER1': 8,
#   'PTGER2': 20,
#   'PTGDR2': 10,
#   'ESR1': 1},
#  'hereditary angioedema with C1Inh deficiency': {'C1S': 555,
#   'C1R': 155,
#   'F12': 401,
#   'KLKB1': 353,
#   'F2': 97,
#   'PLAT': 130,
#   'SERPING1': 485,
#   'F11': 80,
#   'KNG1': 288,
#   'CREB3': 1,
#   'GP1BA': 2,
#   'APP': 1,
#   'CD93': 1,
#   'PITX3': 7,
#   'C1QBP': 1,
#   'C1QA': 1,
#   'ANPEP': 83,
#   'BDKRB2': 69,
#   'SLCO2B1': 123,
#   'SLC22A8': 88,
#   'SLC16A1': 131,
#   'SLC15A1': 94,
#   'C9': 1,
#   'DAO': 48,
#   'UBC': 1,
#   'C2': 1},
#  'otorhinolaryngologic disease': {'BMPR2': 1,
#   'ALB': 1,
#   'POLR1C': 3,
#   'NME1': 3,
#   'POLR1D': 3,
#   'GRB2': 6,
#   'PDE4D': 2,
#   'PRKAR1A': 1},
#  'Kleefstra syndrome': {'GABRG2': 97,
#   'GABRA1': 112,
#   'GABRA3': 64,
#   'GABRA2': 41,
#   'OPRM1': 2,
#   'OXT': 3,
#   'CRH': 3,
#   'HCN1': 1,
#   'P4HTM': 3,
#   'BCHE': 2,
#   'OPRK1': 1,
#   'KNG1': 4,
#   'IQSEC1': 1,
#   'PUS7': 1,
#   'GABRA5': 52,
#   'EHMT1': 479,
#   'ADRA1B': 44,
#   'DRD1': 25,
#   'ADRA2A': 66,
#   'ADRA1A': 54,
#   'ADRA2C': 60,
#   'ADRA2B': 45,
#   'ADRA1D': 33,
#   'TRH': 6,
#   'INS': 1,
#   'SLC5A6': 1,
#   'LEP': 2,
#   'NPY': 1,
#   'NPPB': 1,
#   'AP2M1': 1,
#   'EIF3F': 2,
#   'NR3C1': 1,
#   'ALDH2': 28,
#   'GABRB2': 43,
#   'GABRB3': 64,
#   'GABRD': 52,
#   'GABRG3': 27,
#   'GABRB1': 43,
#   'GABRA6': 25,
#   'GABRA4': 49,
#   'GABRQ': 27,
#   'GABRG1': 34,
#   'APP': 1,
#   'CCK': 3,
#   'IL6': 1,
#   'NOS2': 2,
#   'POMC': 2,
#   'PTGS2': 2,
#   'CACNA1C': 1,
#   'GLUL': 2,
#   'IL1B': 1,
#   'NGF': 1,
#   'SLC6A2': 2,
#   'MPDZ': 2,
#   'EDN1': 1,
#   'NPR1': 12},
#  'inherited neurodegenerative disorder': {'GABRA5': 15,
#   'GABRA1': 14,
#   'GABRA4': 2,
#   'ALB': 3,
#   'TECPR2': 1,
#   'WDR45': 6,
#   'GABRA3': 3,
#   'GABRB1': 2,
#   'GABRA6': 2,
#   'GABRD': 5,
#   'GABRG3': 2,
#   'GABRB3': 9,
#   'CHRNA4': 5,
#   'ABCC2': 5,
#   'NR1I2': 1,
#   'GRIN2A': 2,
#   'GRIN2D': 3,
#   'CASR': 1,
#   'CRH': 4,
#   'POMC': 6,
#   'DNM1': 4,
#   'SCN1A': 4,
#   'HCN1': 3,
#   'GRIN2B': 4,
#   'SCN2A': 2,
#   'TBCD': 3,
#   'PHACTR1': 1,
#   'PNKP': 3,
#   'CUX2': 2,
#   'GRIN1': 2,
#   'DRD2': 33,
#   'DRD3': 13,
#   'DRD4': 10,
#   'ADRA2A': 6,
#   'HTR1A': 18,
#   'BDNF': 7,
#   'BST1': 7,
#   'EDN1': 8,
#   'GFAP': 7,
#   'GPX1': 7,
#   'HGF': 6,
#   'KCNJ4': 7,
#   'ABCB1': 6,
#   'TH': 6,
#   'BAG5': 7,
#   'TCL1B': 7,
#   'CNTNAP2': 6,
#   'PINK1': 8,
#   'BCHE': 3,
#   'SLC22A2': 1,
#   'SLC22A1': 1,
#   'VCP': 1,
#   'GABRA2': 1,
#   'GABRG2': 2},
#  'de Barsy syndrome': {'ALDH18A1': 291,
#   'LGALS3': 13,
#   'GLTP': 13,
#   'GLT6D1': 1,
#   'UBC': 5,
#   'IL1B': 15,
#   'UGT1A6': 9,
#   'ALB': 23,
#   'ABCB1': 35,
#   'SLC7A5': 37,
#   'THRA': 40,
#   'SLCO4A1': 31,
#   'SLCO1C1': 20,
#   'SLCO4C1': 15,
#   'UGT1A1': 9,
#   'SLC10A1': 9,
#   'SERPINA7': 6,
#   'SLCO1B3': 6,
#   'SUMO1': 1,
#   'PROC': 10,
#   'PROS1': 18},
#  'reactive arthritis': {'HSD11B1': 33,
#   'ABCB1': 574,
#   'ABCG2': 55,
#   'COL2A1': 24,
#   'ZFP36': 6,
#   'NR3C1': 121,
#   'ABCB11': 86,
#   'ALB': 608,
#   'NOS2': 24,
#   'SLC22A8': 99,
#   'SLCO1A2': 116,
#   'NR1I2': 22,
#   'IFNA2': 44,
#   'IL1RN': 22,
#   'IL6': 34,
#   'MVK': 14,
#   'PRL': 6,
#   'PTGS2': 74,
#   'STAT3': 16,
#   'TNF': 33,
#   'MECP2': 7,
#   'OXT': 15,
#   'CCK': 5,
#   'ASPG': 6,
#   'OPRM1': 10,
#   'PDYN': 8,
#   'TBCD': 7,
#   'TNFRSF1A': 5,
#   'MGME1': 5,
#   'BCHE': 4,
#   'SERPINA6': 57,
#   'CXCL8': 10,
#   'IGF1R': 3,
#   'SHBG': 9,
#   'SRD5A2': 3,
#   'AKR1D1': 10,
#   'IFNG': 3,
#   'SOD2': 1,
#   'SOD1': 6,
#   'MAPT': 2,
#   'POMC': 5},
#  'supratentorial cancer': {'EWSR1': 2,
#   'JUN': 28,
#   'CTNNB1': 33,
#   'IL2': 7,
#   'PMS2': 981,
#   'PTEN': 25,
#   'YAP1': 21,
#   'ABCB1': 75,
#   'TUBD1': 14,
#   'TUBG1': 18,
#   'TUBB': 20,
#   'TUBA1A': 17,
#   'ABCC6': 31,
#   'TUBE1': 13,
#   'ABCC2': 47,
#   'ABCB11': 16,
#   'SLCO1B1': 4,
#   'TRMO': 1,
#   'UBC': 30,
#   'MYC': 24,
#   'BRCA1': 27,
#   'BRIP1': 25,
#   'HES1': 8,
#   'NOTCH2': 13,
#   'PON1': 2,
#   'HEY1': 5,
#   'CDKN2A': 17,
#   'HRAS': 6,
#   'VEGFA': 3,
#   'NR1I2': 12,
#   'S100B': 2,
#   'MAPT': 25,
#   'MAP2': 22,
#   'ABCC1': 29,
#   'BCL2': 30,
#   'TUBB1': 10,
#   'MAP4': 24,
#   'SLCO1B3': 7,
#   'CLSPN': 3,
#   'XRCC3': 2,
#   'MSH3': 1,
#   'RRM1': 14,
#   'EGFR': 4,
#   'IDH1': 3,
#   'SOD2': 8,
#   'TOP2A': 18,
#   'CBR1': 15,
#   'TLR3': 12,
#   'TLR2': 16,
#   'ALB': 32,
#   'NDUFS3': 14,
#   'AKR1C3': 16,
#   'NOS1': 13,
#   'NQO1': 15,
#   'ABCB8': 16,
#   'NDUFS2': 14,
#   'NFYB': 2,
#   'NSF': 1,
#   'MTHFR': 23,
#   'ABCC5': 24,
#   'PPAT': 20,
#   'UMPS': 24,
#   'SLC22A7': 13,
#   'UPP2': 11,
#   'TYMS': 50,
#   'DPYD': 23,
#   'TYMP': 23,
#   'SERPINA7': 4,
#   'POLR1H': 3,
#   'MEOX2': 1,
#   'MCM3': 1},
#  'nephrogenic syndrome of inappropriate antidiuresis': {'AVPR2': 233,
#   'ABCB1': 61,
#   'AVPR1A': 35,
#   'OXT': 13,
#   'TRH': 1,
#   'SLC5A6': 2,
#   'LEP': 1,
#   'CCK': 1,
#   'TRPV4': 4,
#   'AVP': 5,
#   'IFNG': 5,
#   'UBC': 2,
#   'GRK5': 1,
#   'PRKCA': 2,
#   'ARRB2': 1,
#   'CACNA1G': 13,
#   'SLC12A5': 1,
#   'SLC2A1': 1,
#   'GABRG2': 14,
#   'GABRA1': 17,
#   'GABRA2': 16,
#   'GABRA3': 14,
#   'CNR1': 2,
#   'CRH': 3,
#   'DRD2': 2,
#   'HTR1A': 3,
#   'OPRM1': 1,
#   'PUM1': 1,
#   'P4HTM': 3,
#   'NTNG2': 1,
#   'HCN1': 1,
#   'GABRA5': 1,
#   'COMT': 2,
#   'VCP': 1,
#   'IL1B': 2,
#   'IL6': 1,
#   'MTHFR': 1,
#   'PTGS2': 2,
#   'ALDH2': 11,
#   'NPR1': 16,
#   'GATA2': 1},
#  'trichothiodystrophy': {'RARA': 164,
#   'RARB': 93,
#   'RARG': 97,
#   'ERCC2': 205,
#   'ERCC3': 263,
#   'GTF2E2': 198,
#   'RNF113A': 161,
#   'MPLKIP': 190,
#   'GTF2H5': 183,
#   'UBC': 24,
#   'CDK7': 6,
#   'CCNH': 6,
#   'PSMC5': 2,
#   'TBP': 1,
#   'ALB': 173,
#   'ABCB1': 160,
#   'ORM1': 67,
#   'OXT': 1,
#   'IL6ST': 1,
#   'ABCG2': 269,
#   'SMO': 129,
#   'ERCC5': 12,
#   'TP53': 4,
#   'CCND1': 2,
#   'XPA': 4,
#   'BLVRB': 1,
#   'PCDH7': 2},
#  'Noonan syndrome-like disorder with loose anagen hair': {'OXTR': 134,
#   'BRAF': 547,
#   'KRAS': 579,
#   'MAP2K1': 549,
#   'MAP2K2': 449,
#   'PTPN11': 548,
#   'RASA1': 465,
#   'RASA2': 412,
#   'RRAS': 416,
#   'SHOC2': 483,
#   'LZTR1': 413,
#   'MRAS': 434,
#   'NRAS': 20,
#   'PRDM14': 4,
#   'GATA2': 15,
#   'AR': 977,
#   'GATA1': 1,
#   'GHR': 226,
#   'PRLR': 164,
#   'NUP107': 2,
#   'CAT': 3,
#   'RAP1GDS1': 25,
#   'PKP2': 6,
#   'CTNND1': 4,
#   'UBC': 72,
#   'ARMC8': 18,
#   'ANKAR': 12,
#   'NEK3': 1,
#   'STAT5A': 2,
#   'SOCS1': 2,
#   'PTPN6': 1,
#   'GRB2': 15,
#   'ZMIZ1': 2,
#   'NR3C1': 412,
#   'SHBG': 354,
#   'HSD11B2': 176,
#   'NFE2L2': 2,
#   'CBL': 4,
#   'RPS6KA2': 6,
#   'EEF1A1': 12,
#   'ETS1': 24,
#   'CALM2': 1,
#   'MLH3': 4,
#   'BMPR1A': 4,
#   'BRCA1': 3,
#   'TEK': 2,
#   'PAF1': 1,
#   'CD28': 4,
#   'IRF8': 1,
#   'CBLB': 3,
#   'ERBB4': 4,
#   'CSK': 2,
#   'HTT': 2,
#   'MAX': 2,
#   'REPS2': 2,
#   'EHMT1': 1,
#   'ZNF451': 2,
#   'PARP1': 3,
#   'E2F1': 4,
#   'PKLR': 2,
#   'SRD5A3': 322,
#   'MN1': 1,
#   'ESR1': 443,
#   'MAOA': 499,
#   'ALB': 225,
#   'ABCB1': 398,
#   'SLCO1A2': 239,
#   'SRD5A2': 144,
#   'SLC22A7': 293,
#   'SLC10A1': 97,
#   'MAP3K1': 2,
#   'FKBPL': 2,
#   'LGALS3': 2,
#   'MAPK14': 3,
#   'ERBB2': 2,
#   'HUWE1': 2,
#   'CDCA3': 1,
#   'WWP1': 1},
#  'neuronopathy, distal hereditary motor': {'SOD1': 6,
#   'VIM': 227,
#   'PRDX3': 188,
#   'HSPB1': 211,
#   'HSPB3': 56,
#   'FBXO38': 157,
#   'SMN1': 1,
#   'SMN2': 2,
#   'PLEKHG5': 2,
#   'TRPV4': 2,
#   'SLC25A46': 1,
#   'DCTN1': 167,
#   'GARS1': 28,
#   'DNM1L': 1,
#   'PNPLA6': 191,
#   'IGF1R': 242,
#   'INSR': 247,
#   'BSCL2': 90,
#   'SLC5A7': 61,
#   'WARS1': 31,
#   'UBC': 40,
#   'EHD1': 2,
#   'STYX': 2,
#   'IDE': 1,
#   'IGF2R': 232,
#   'ARMC6': 1,
#   'ARMC7': 1,
#   'PKP2': 1,
#   'GSK3B': 1,
#   'GFAP': 2,
#   'ASNS': 2,
#   'NEFH': 1,
#   'VCP': 1,
#   'ABCG2': 226,
#   'SCN5A': 114,
#   'SLC7A11': 185,
#   'AKT1': 6,
#   'CRYAB': 2,
#   'FLOT1': 1,
#   'JUN': 1,
#   'LAT': 1,
#   'OPTN': 1,
#   'TNF': 3,
#   'PARK7': 1}}

# %%
all_path['gene occurences for this disease'] = all_path.apply(lambda x: {i: gene_count_per_path_per_disease[x.Disease][i] for i in x.genes}, axis = 1)

# %%
all_path['number of paths for this disease'] = all_path.Disease.apply(lambda x: path_count_per_disease[x])

# %%
all_path = all_path[~all_path.Category.isin(['Recent Approved Diseases', 'Approved Pairs'])]
all_path = all_path.rename(columns = {'gene occurences(out of 335752 paths)': 'gene occurences across all paths'})

# %%
all_path.to_pickle('paths.pkl')

# %%
all_path.to_csv('paths.csv', index = False)

# %%
all_path.sort_values('Path Score')[::-1]
# Out:
#                                                 Disease          Drug  \
# 125                                  mevalonic aciduria   Canakinumab
# 63                 disorder of phenylalanine metabolism   Sapropterin
# 148                               pancreatic insulinoma     Diazoxide
# 856   nephrogenic syndrome of inappropriate antidiur...     Tolvaptan
# 141         hereditary angioedema with C1Inh deficiency   Ecallantide
# ...                                                 ...           ...
# 3689                         deafness dystonia syndrome  Testosterone
# 3659                         deafness dystonia syndrome  Testosterone
# 3658                         deafness dystonia syndrome  Testosterone
# 3660                         deafness dystonia syndrome  Testosterone
# 4599                                           seminoma   Doxorubicin
#
#                                               Meta-Path  \
# 125                       disease -> indication -> drug
# 63                        disease -> indication -> drug
# 148                       disease -> indication -> drug
# 856                       disease -> indication -> drug
# 141                       disease -> indication -> drug
# ...                                                 ...
# 3689  disease -> disease_protein -> gene/protein -> ...
# 3659  disease -> disease_protein -> gene/protein -> ...
# 3658  disease -> disease_protein -> gene/protein -> ...
# 3660  disease -> disease_protein -> gene/protein -> ...
# 4599  disease -> disease_protein -> gene/protein -> ...
#
#                                                    Path  Path Score  \
# 125     mevalonic aciduria -> indication -> Canakinumab    1.995601
# 63    disorder of phenylalanine metabolism -> indica...    1.978879
# 148    pancreatic insulinoma -> indication -> Diazoxide    1.971971
# 856   nephrogenic syndrome of inappropriate antidiur...    1.967655
# 141   hereditary angioedema with C1Inh deficiency ->...    1.952124
# ...                                                 ...         ...
# 3689  deafness dystonia syndrome -> disease_protein ...    0.026248
# 3659  deafness dystonia syndrome -> disease_protein ...    0.025970
# 3658  deafness dystonia syndrome -> disease_protein ...    0.025734
# 3660  deafness dystonia syndrome -> disease_protein ...    0.025653
# 4599  seminoma -> disease_protein -> ERCC4 -> exposu...    0.025645
#
#       Prediction Score                                           Category  \
# 125           0.982810    metabolic_disorder-disease-few-indications-top3
# 63            0.999842    cell_proliferation-disease-few-indications-top3
# 148           0.999731    metabolic_disorder-disease-few-indications-top3
# 856           0.999577     neurodigenerative-disease-few-indications-top3
# 141           0.999559    metabolic_disorder-disease-few-indications-top3
# ...                ...                                                ...
# 3689          0.995375  autoimmune-disease-zero-indications-top3-num-n...
# 3659          0.995375  autoimmune-disease-zero-indications-top3-num-n...
# 3658          0.995375  autoimmune-disease-zero-indications-top3-num-n...
# 3660          0.995375  autoimmune-disease-zero-indications-top3-num-n...
# 4599          0.997857                anemia-disease-few-indications-top3
#
#               genes gene occurences across all paths  \
# 125              []                               {}
# 63               []                               {}
# 148              []                               {}
# 856              []                               {}
# 141              []                               {}
# ...             ...                              ...
# 3689     [TBP, AHR]           {'TBP': 858, 'AHR': 4}
# 3659          [TBP]                     {'TBP': 858}
# 3658          [TBP]                     {'TBP': 858}
# 3660          [TBP]                     {'TBP': 858}
# 4599  [ERCC4, TLR2]      {'ERCC4': 827, 'TLR2': 249}
#
#      gene occurences for this disease  number of paths for this disease
# 125                                {}                               349
# 63                                 {}                               398
# 148                                {}                               503
# 856                                {}                              5273
# 141                                {}                              1827
# ...                               ...                               ...
# 3689           {'TBP': 841, 'AHR': 3}                              7565
# 3659                     {'TBP': 841}                              7565
# 3658                     {'TBP': 841}                              7565
# 3660                     {'TBP': 841}                              7565
# 4599      {'ERCC4': 827, 'TLR2': 232}                              9622
#
# [238108 rows x 11 columns]

# %%
all_path_exclude = all_path[~all_path['Meta-Path'].str.contains('indication')]
all_path_exclude = all_path_exclude[~all_path_exclude['Meta-Path'].str.contains('exposure')]
all_path_exclude = all_path_exclude[~all_path_exclude['Meta-Path'].str.contains('drug_effect')]

# %%
all_path_exclude = all_path_exclude[~all_path_exclude['Category'].str.contains('cell_proliferation')]

# %%
all_path_exclude.reset_index(drop = True).to_csv('paths_filter.csv', index = False)

# %%
len(all_path.Disease.unique())
# Out:
# 42

# %%
idx_gene
# Out:
# [6]

# %%
[all_path['Path'].values[0].split('->')[gene].strip() for gene in idx_gene]
# Out:
# ['EPAS1']

# %%
## diseases with a few indications
disease_few_indications = result[result.Name.isin(disease_in_the_area) & (result.number_of_indications >= 1) & (result.number_of_indications < 5) & (result.number_of_neighbors != 0)].Name.values
## diseases with zero indications but many neighbors
disease_zero_indications_many_neighbors = result[result.Name.isin(disease_in_the_area) & (result.number_of_indications == 0) & (result.number_of_neighbors != 0)].sort_values('number_of_neighbors')[::-1].Name.values[:5]

# %%
disease_in_the_area
# Out:
# ['Faye-Petersen-Ward-Carey syndrome',
#  'carcinoma of urethra',
#  'cornea cancer',
#  'glycine metabolism disease',
#  'Trichomonas cervicitis',
#  'cervical hypertrichosis with underlying kyphoscoliosis',
#  'middle ear squamous cell carcinoma',
#  'carotid artery occlusion',
#  'X-linked recessive ocular albinism',
#  'primary brain neoplasm',
#  'gershinibaruch Leibo syndrome',
#  'flat urothelial hyperplasia',
#  'common bile duct neoplasm',
#  'delusional disorder',
#  'gastrin-producing neuroendocrine tumor',
#  'acanthosis nigricans (disease)',
#  'amaurosis fugax',
#  'Crohn jejunoileitis',
#  'deafness-ear malformation-facial palsy syndrome',
#  'premenstrual tension',
#  'uterine corpus adenosarcoma',
#  'recurrent hypersomnia',
#  'accommodative esotropia',
#  'mixed hepatoblastoma',
#  'intramural coronary arterial course',
#  'stage II endometrioid carcinoma',
#  'Liang-Wang syndrome',
#  'Klebsiella pneumonia',
#  'pancreatic intraductal papillary-mucinous neoplasm with low grade dysplasia',
#  'ovarian cyst (disease)',
#  'benign basal cell neoplasm',
#  'pupil disease',
#  'microcephaly sparse hair intellectual disability seizures',
#  'portal vein, cavernous transformation of',
#  'breast adenomyoepithelial adenosis',
#  'lethal arthrogryposis-anterior horn cell disease syndrome',
#  'trichothiodystrophy',
#  'short stature-heart defect-craniofacial anomalies syndrome',
#  'D,L-2-hydroxyglutaric aciduria',
#  'diffuse neonatal hemangiomatosis',
#  'obsolete familial combined hyperlipidemia',
#  'blepharophimosis - intellectual disability syndrome, MKB type',
#  'disorder of other vitamins and cofactors metabolism and transport',
#  'cardiocranial syndrome, Pfeiffer type',
#  'muscular atrophy-ataxia-retinitis pigmentosa-diabetes mellitus syndrome',
#  'Bartsocas-Papas syndrome',
#  'inosine phosphorylase deficiency, immune defect due to',
#  'neuronopathy, distal hereditary motor',
#  'nephrogenic syndrome of inappropriate antidiuresis',
#  'adenocarcinoma of skene gland origin',
#  'Gaucher disease',
#  'oral erosive lichen',
#  'ptosis-syndactyly-learning difficulties syndrome',
#  'larynx cancer',
enrichment = False

xai2path = {}
for name, G in G_dict.items():
    print(name)
    xai2path[name] = find_meta_paths(X_id, Y_id, G, not_cool_rel, relation_avg_dict[name], enrichment = enrichment)
# Out:
# att
# Number of neighbors:  609
# 0it [00:00, ?it/s]
# 1it [00:00,  5.57it/s]
# 3it [00:00,  5.64it/s]
# 9it [00:00, 17.94it/s]
# 19it [00:00, 37.49it/s]
# 27it [00:00, 47.26it/s]
# 34it [00:00, 52.23it/s]
# 43it [00:01, 62.19it/s]
# 53it [00:01, 72.64it/s]
# 62it [00:01, 73.61it/s]
# 73it [00:01, 82.29it/s]
# 84it [00:01, 88.55it/s]
# 100it [00:01, 105.60it/s]
# 111it [00:01, 91.23it/s]
# 121it [00:01, 93.00it/s]
# 131it [00:01, 91.26it/s]
# 141it [00:02, 77.41it/s]
# 150it [00:02, 80.00it/s]
# 159it [00:02, 81.18it/s]
# 170it [00:02, 86.70it/s]
# 179it [00:02, 84.78it/s]
# 189it [00:02, 85.87it/s]
# 200it [00:02, 89.85it/s]
# 210it [00:02, 84.73it/s]
# 219it [00:03, 84.36it/s]
# 229it [00:03, 88.24it/s]
# 238it [00:03, 77.98it/s]
# 248it [00:03, 80.21it/s]
# 258it [00:03, 84.86it/s]
# 269it [00:03, 87.15it/s]
# 278it [00:03, 84.12it/s]
# 289it [00:03, 90.52it/s]
# 302it [00:03, 100.03it/s]
# 313it [00:04, 68.28it/s]
# 322it [00:04, 56.94it/s]
# 329it [00:04, 55.85it/s]
# 336it [00:04, 58.15it/s]
# 343it [00:05, 39.71it/s]
# 352it [00:05, 47.94it/s]
# 362it [00:05, 57.78it/s]
# 372it [00:05, 65.69it/s]
# 380it [00:05, 68.45it/s]
# 391it [00:05, 78.23it/s]
# 403it [00:05, 88.90it/s]
# 414it [00:05, 87.96it/s]
# 427it [00:05, 93.34it/s]
# 437it [00:06, 94.64it/s]
# 447it [00:06, 94.11it/s]
# 457it [00:06, 88.71it/s]
# 469it [00:06, 96.11it/s]
# 482it [00:06, 101.75it/s]
# 493it [00:06, 91.38it/s]
# 503it [00:06, 85.36it/s]
# 512it [00:06, 84.35it/s]
# 523it [00:06, 90.96it/s]
# 533it [00:07, 87.95it/s]
# 543it [00:07, 89.41it/s]
# 553it [00:07, 86.45it/s]
# 563it [00:07, 87.65it/s]
# 574it [00:07, 90.59it/s]
# 584it [00:07, 90.96it/s]
# 594it [00:07, 91.36it/s]
# 604it [00:08, 69.61it/s]
# 615it [00:08, 71.32it/s]
# gm
# Number of neighbors:  715
# 0it [00:00, ?it/s]
# 1it [00:00,  4.12it/s]
# 4it [00:00, 12.32it/s]
# 6it [00:00,  8.62it/s]
# 11it [00:00, 16.83it/s]
# 18it [00:00, 28.65it/s]
# 26it [00:01, 40.38it/s]
# 34it [00:01, 49.42it/s]
# 42it [00:01, 57.38it/s]
# 50it [00:01, 60.23it/s]
# 57it [00:01, 61.67it/s]
# 66it [00:01, 67.16it/s]
# 78it [00:01, 79.99it/s]
# 91it [00:01, 93.52it/s]
# 619it [00:11, 55.25it/s]
# 626it [00:12, 55.84it/s]
# 634it [00:12, 61.73it/s]
# 641it [00:12, 54.73it/s]
# 649it [00:12, 58.39it/s]
# 656it [00:12, 58.06it/s]
# 663it [00:12, 58.23it/s]
# 670it [00:12, 58.58it/s]
# 678it [00:12, 62.42it/s]
# 688it [00:13, 49.52it/s]

# %%
print_beautiful_paths(xai2path['att'][-1])
# Out:
# ['disease -> disease_disease -> disease -> disease_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_disease -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_phenotype_positive -> effect/phenotype -> disease_phenotype_positive -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> anatomy_protein_present -> anatomy -> anatomy_protein_present -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> cellcomp_protein -> cellular_component -> cellcomp_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> disease_protein -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> bioprocess_protein -> biological_process -> bioprocess_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> molfunc_protein -> molecular_function -> molfunc_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> phenotype_protein -> effect/phenotype -> phenotype_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> protein_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> exposure_disease -> exposure -> exposure_bioprocess -> biological_process -> bioprocess_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> exposure_disease -> exposure -> exposure_disease -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> indication -> drug -> drug_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> indication -> drug -> drug_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> indication -> drug -> indication -> disease -> disease_protein -> gene/protein -> drug_protein -> drug']

# %%
## get all paths in a meta path
meta_path = xai2path['att'][-1][8]
print('for meta path: ', meta_path)
print_beautiful_paths(xai2path['att'][2][meta_path])
# Out:
# for meta path:  ('disease', 'rev_disease_protein', 'gene/protein', 'phenotype_protein', 'effect/phenotype', 'rev_phenotype_protein', 'gene/protein', 'rev_drug_protein', 'drug')
# ['macular degeneration -> disease_protein -> APOE -> phenotype_protein -> Proteinuria -> phenotype_protein -> VEGFA -> drug_protein -> Faricimab']

# %%
## get all paths in a meta path
meta_path = xai2path['att'][-1][6]
print('for meta path: ', meta_path)
print_beautiful_paths(xai2path['att'][2][meta_path])
# Out:
# for meta path:  ('disease', 'rev_disease_protein', 'gene/protein', 'bioprocess_protein', 'biological_process', 'rev_bioprocess_protein', 'gene/protein', 'rev_drug_protein', 'drug')
# ['macular degeneration -> disease_protein -> APOE -> bioprocess_protein -> negative regulation of gene expression -> bioprocess_protein -> VEGFA -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_protein -> APOE -> bioprocess_protein -> gene expression -> bioprocess_protein -> ANGPT2 -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_protein -> HTRA1 -> bioprocess_protein -> positive regulation of epithelial cell proliferation -> bioprocess_protein -> VEGFA -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_protein -> VEGFA -> bioprocess_protein -> angiogenesis -> bioprocess_protein -> ANGPT2 -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_protein -> VEGFA -> bioprocess_protein -> positive regulation of angiogenesis -> bioprocess_protein -> ANGPT2 -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_protein -> SQSTM1 -> bioprocess_protein -> positive regulation of protein phosphorylation -> bioprocess_protein -> VEGFA -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_protein -> SQSTM1 -> bioprocess_protein -> negative regulation of transcription by RNA polymerase II -> bioprocess_protein -> VEGFA -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_protein -> FGD6 -> bioprocess_protein -> regulation of cell shape -> bioprocess_protein -> VEGFA -> drug_protein -> Faricimab']

# %%
print_beautiful_paths(xai2path['gm'][-1])
# Out:
# ['disease -> disease_disease -> disease -> disease_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_disease -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_disease -> disease -> disease_disease -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_phenotype_positive -> effect/phenotype -> disease_phenotype_positive -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> anatomy_protein_present -> anatomy -> anatomy_protein_present -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> bioprocess_protein -> biological_process -> bioprocess_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> cellcomp_protein -> cellular_component -> cellcomp_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> disease_protein -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> molfunc_protein -> molecular_function -> molfunc_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> phenotype_protein -> effect/phenotype -> phenotype_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> protein_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> exposure_disease -> exposure -> exposure_disease -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> indication -> drug -> drug_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> indication -> drug -> drug_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> indication -> drug -> indication -> disease -> disease_protein -> gene/protein -> drug_protein -> drug']

# %%
## get all paths in a meta path
meta_path = xai2path['gm'][-1][3]
print('for meta path: ', meta_path)
print_beautiful_paths(xai2path['gm'][2][meta_path])
# Out:
# for meta path:  ('disease', 'disease_phenotype_positive', 'effect/phenotype', 'rev_disease_phenotype_positive', 'disease', 'rev_disease_protein', 'gene/protein', 'rev_drug_protein', 'drug')
# ['macular degeneration -> disease_phenotype_positive -> Autosomal dominant inheritance -> disease_phenotype_positive -> lung cancer -> disease_protein -> VEGFA -> drug_protein -> Faricimab',
#  'macular degeneration -> disease_phenotype_positive -> Autosomal dominant inheritance -> disease_phenotype_positive -> cystoid macular edema -> disease_protein -> VEGFA -> drug_protein -> Faricimab']

# %%
print_beautiful_paths(xai2path['ge'][-1])
# Out:
# ['disease -> disease_protein -> gene/protein -> anatomy_protein_present -> anatomy -> anatomy_protein_present -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> cellcomp_protein -> cellular_component -> cellcomp_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> disease_protein -> disease -> disease_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> molfunc_protein -> molecular_function -> molfunc_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> bioprocess_protein -> biological_process -> bioprocess_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> pathway_protein -> pathway -> pathway_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> disease_protein -> gene/protein -> protein_protein -> gene/protein -> protein_protein -> gene/protein -> drug_protein -> drug',
#  'disease -> indication -> drug -> drug_effect -> effect/phenotype -> disease_phenotype_positive -> disease -> indication -> drug']

# %%
## get all paths in a meta path
meta_path = xai2path['ge'][-1][-8]
print('for meta path: ', meta_path)
print_beautiful_paths(xai2path['ge'][2][meta_path])
# Out:
# for meta path:  ('disease', 'rev_disease_protein', 'gene/protein', 'anatomy_protein_present', 'anatomy', 'rev_anatomy_protein_present', 'gene/protein', 'rev_drug_protein', 'drug')
# ['Dravet syndrome -> disease_protein -> GABRA1 -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> GABRG2 -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> PMP22 -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> PMP22 -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> POMC -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> POMC -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SCN1A -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SCN1A -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SCN1B -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SCN1B -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SCN2A -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SCN2A -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SCN9A -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> RAPGEF2 -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> RAPGEF2 -> anatomy_protein_present -> palpebral conjunctiva -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> RAPGEF2 -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> TNRC6A -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> TNRC6A -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> PCDH19 -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SAMD12 -> anatomy_protein_present -> adult mammalian kidney -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon',
#  'Dravet syndrome -> disease_protein -> SAMD12 -> anatomy_protein_present -> cerebellar cortex -> anatomy_protein_present -> MTNR1A -> drug_protein -> Tasimelteon']

# %%
## save paths
expand_xai_name ={
    'att': 'attention', 
    'ge': 'gnnexplainer', 
    'gm': 'graphmask'
}
for explainer in ['att', 'ge', 'gm']:
    to_save = []
    for meta_path, paths in xai2path[explainer][2].items():
        if meta_path in xai2path[explainer][-1]:
            path_scores = [score_path_enrichment(G, path, relation_avg_dict[explainer], enrichment) for path in paths]
            to_save += tuple(zip([print_beautiful_path(meta_path)] * len(path_scores), print_beautiful_paths(paths), path_scores))
    pd.DataFrame(to_save).rename(columns = {0: 'Meta-Path', 1: 'Path', 2: 'Path Score'}).to_csv(X_id + '_' + Y_id + '_xai_' + expand_xai_name[explainer] + '.csv', index = False)
